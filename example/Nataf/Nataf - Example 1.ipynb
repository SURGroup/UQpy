# %% [markdown]
# # Nataf Transformation: Example 1 - Uncorrelated Random Variables
#
# Author: Dimitris G. Giovanis,
# Date: June 25, 2018

# %% [markdown]
# Description: Transform uncorrelated standard normal random variables to specified non-Gaussian marginal distributions.

# %%
from UQpy.SampleMethods import MCS, Nataf, Correlate
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Part 1: Generate independent standard normal variables using UQpy MCS

# %%
x = MCS(dimension=2, dist_name=['Normal', 'Normal'], dist_params=[[0, 1], [0, 1]], nsamples=1000)
# Out:
# UQpy: Performing MCS design...
# Done!

# %%
# Plot the distribution of the variables in the standard normal space
fig, ax = plt.subplots()
plt.title('Histogram:parameter #1~N(0, 1)')
plt.hist(x.samples[:, 0])
ax.yaxis.grid(True)
ax.xaxis.grid(True)

fig, ax = plt.subplots()
plt.title('Histogram:parameter #2~N(0, 1)')
plt.hist(x.samples[:, 1])
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %% [markdown]
# Transform the standard normal random variables to:
# - Lognormal(1,2)
# - Gamma(2,1)

# %%
z = Nataf(samples=x, dist_name=['Lognormal', 'Gamma'], dist_params=[[1, 2], [2, 1]])
# Out:
# UQpy: Computing Nataf correlation distortion...
# Done.
# UQpy: Performing Nataf transformation of the samples...
# Done.

# %% [markdown]
# Plot the histogram of the transformed samples.

# %%
fig, ax = plt.subplots()
plt.title('Histogram:parameter #1~Lognormal(1, 2)')
plt.hist(z.samples[:, 0])
ax.yaxis.grid(True)
ax.xaxis.grid(True)

fig, ax = plt.subplots()
plt.title('Histogram:parameter #2~Γ(2, 1)')
plt.hist(z.samples[:, 1])
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %% [markdown]
# Plot the transformed samples.

# %%
plt.figure()
plt.title('Uncorrelated samples in the non-Gaussian space')
plt.scatter(z.samples[:, 0], z.samples[:, 1])
plt.grid(True)

   
plt.figure()
plt.title('Uncorrelated samples in the standard normal space')
plt.scatter(z.samplesN01[:, 0], z.samplesN01[:, 1])
plt.grid(True)
plt.xlabel('X_1')
plt.ylabel('X_2')
plt.show()

# %% [markdown]
# Part 2: Define the samples as an array

# %%
x0 = np.random.randn(1000, 2)

# %% [markdown]
# Transform the standard normal random variables to:
# - Lognormal(1,2)
# - Gamma(2,1)

# %%
z0 = Nataf(samples=x0, dist_name=['Lognormal', 'Gamma'], dist_params=[[1, 2], [2, 1]], dimension=2)
# Out:
# UQpy: Computing Nataf correlation distortion...
# Done.
# UQpy: Performing Nataf transformation of the samples...
# Done.

# %% [markdown]
# Plot the histogram of the transformed samples.

# %%
fig, ax = plt.subplots()
plt.title('Histogram:parameter #1~Lognormal(1, 2)')
plt.hist(z0.samples[:, 0])
ax.yaxis.grid(True)
ax.xaxis.grid(True)

fig, ax = plt.subplots()
plt.title('Histogram:parameter #2~Γ(2, 1)')
plt.hist(z0.samples[:, 1])
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %% [markdown]
# Plot the transformed samples.

# %%
plt.figure()
plt.title('Uncorrelated samples in the non-Gaussian space')
plt.scatter(z0.samples[:, 0], z0.samples[:, 1])
plt.grid(True)

   
plt.figure()
plt.title('Uncorrelated samples in the standard normal space')
plt.scatter(z0.samplesN01[:, 0], z0.samplesN01[:, 1])
plt.grid(True)
plt.xlabel('X_1')
plt.ylabel('X_2')
plt.show()
