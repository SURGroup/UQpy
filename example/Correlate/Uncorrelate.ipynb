# %% [markdown]
# # Uncorrelate samples
#
# Author: Dimitris G. Giovanis,
# Date: June 25, 2018

# %% [markdown]
# In this example, the class 'Unorrelate' is employed to decorrelate standard normal samples generated with the UQpy Correlate class.

# %%
from UQpy.SampleMethods import MCS, Correlate, Uncorrelate
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate uncorrelated standard normal samples
x = MCS(dimension=2, dist_name=['Normal', 'Normal'], dist_params=[[0, 1], [0, 1]], nsamples=1000)
# Define the correlation matrix of samples N(0, 1)
Rho = np.array([[1.0, 0.9], [0.9, 1.0]])
# Correlate the samples
y = Correlate(x, corr_norm=Rho)
# Out:
# UQpy: Performing MCS design...
# Done!
# Correlating standard normal samples...

# %%
# Plot the distribution of the variables in the standard normal space
fig, ax = plt.subplots()
plt.title('Uncorrelated samples in N(0, 1)')
plt.scatter(x.samples[:, 0], x.samples[:, 1])
ax.yaxis.grid(True)
ax.xaxis.grid(True)

fig, ax = plt.subplots()
plt.title('Correlated samples in N(0, 1)')
plt.scatter(y.samples_corr[:, 0], y.samples_corr[:, 1])
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()

# %%
# Use class 'Uncorrelate' to decorrelate the samples
y0 = Uncorrelate(y, corr_norm=Rho)

# %%
# Plot the distribution of the variables in the standard normal space
fig, ax = plt.subplots()
plt.title('Uncorrelated samples in N(0, 1)')
plt.scatter(y0.samples_uncorr[:, 0], y0.samples_uncorr[:, 1])
ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.show()
