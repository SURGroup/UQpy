# %% [markdown]
# # Active Kriging-Monte Carlo Simulation Example 1

# %% [markdown]
# Author: Mohit S. Chauhan
# Date: May 20, 2020

# %% [markdown]
# In this example, Monte Carlo Sampling is used to generate samples from Normal distribution and new samples are generated adaptively, using U-function as the learning criteria .

# %% [markdown]
# Import the necessary libraries. Here we import standard libraries such as numpy, matplotlib and other necessary library for plots, but also need to import the MCS, AKMCS, Kriging and RunModel class from UQpy.

# %%
from UQpy.surrogates import Kriging
from UQpy.sampling import MonteCarloSampling, AdaptiveKriging
from UQpy.RunModel import RunModel
from UQpy.distributions import Normal
from series import series
import numpy as np
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plt
import time
from UQpy.optimization.MinimizeOptimizer import MinimizeOptimizer
# Out:
# /opt/anaconda3/envs/UQpy_39/lib/python3.9/site-packages/beartype/_util/hint/pep/utilpeptest.py:396: BeartypeDecorHintPepDeprecatedWarning: Type hint typing.List[typing.Callable] deprecated by PEP 585. To resolve this, globally replace this hint by the equivalent PEP 585 type hint (e.g., "typing.List[int]" by "list[int]"). See also:
#     https://www.python.org/dev/peps/pep-0585
#   warn(warning_message, BeartypeDecorHintPepDeprecatedWarning)
# /opt/anaconda3/envs/UQpy_39/lib/python3.9/site-packages/beartype/_util/hint/pep/utilpeptest.py:396: BeartypeDecorHintPepDeprecatedWarning: Type hint typing.Callable deprecated by PEP 585. To resolve this, globally replace this hint by the equivalent PEP 585 type hint (e.g., "typing.List[int]" by "list[int]"). See also:
#     https://www.python.org/dev/peps/pep-0585
#   warn(warning_message, BeartypeDecorHintPepDeprecatedWarning)
# /opt/anaconda3/envs/UQpy_39/lib/python3.9/site-packages/beartype/_util/hint/pep/utilpeptest.py:396: BeartypeDecorHintPepDeprecatedWarning: Type hint typing.Callable deprecated by PEP 585. To resolve this, globally replace this hint by the equivalent PEP 585 type hint (e.g., "typing.List[int]" by "list[int]"). See also:
#     https://www.python.org/dev/peps/pep-0585
#   warn(warning_message, BeartypeDecorHintPepDeprecatedWarning)
# /opt/anaconda3/envs/UQpy_39/lib/python3.9/site-packages/beartype/_util/hint/pep/utilpeptest.py:396: BeartypeDecorHintPepDeprecatedWarning: Type hint typing.List[typing.Union[UQpy.sampling.ImportanceSampling.ImportanceSampling, UQpy.sampling.mcmc.baseclass.MCMC.MCMC]] deprecated by PEP 585. To resolve this, globally replace this hint by the equivalent PEP 585 type hint (e.g., "typing.List[int]" by "list[int]"). See also:
#     https://www.python.org/dev/peps/pep-0585
#   warn(warning_message, BeartypeDecorHintPepDeprecatedWarning)
# The selected optimizer method does not support bounds and thus will be ignored.
# The selected optimizer method does not support bounds and thus will be ignored.

# %% [markdown]
# Using UQpy MCS class to generate samples for two random variables, which are normally distributed with mean 0 and variance 1.

# %%
marginals = [Normal(loc=0., scale=4.), Normal(loc=0., scale=4.)]
x = MonteCarloSampling(distributions=marginals, nsamples=20, random_state=1)

# %% [markdown]
# RunModel class is used to define an object to evaluate the model at sample points.

# %%
rmodel = RunModel(model_script='series.py', vec=False)

# %% [markdown]
# Krig class defines an object to generate an surrogate model for a given set of data.

# %%
from UQpy.surrogates.kriging.regression_models import Linear
from UQpy.surrogates.kriging.correlation_models import Exponential
optimizer = MinimizeOptimizer(method="L-BFGS-B")
K = Kriging(regression_model=Linear(), correlation_model=Exponential(), optimizer=optimizer,
            correlation_model_parameters=[1, 1], optimizations_number=10)

# %% [markdown]
# This example works for all three learning function based on reliability analysis.

# %% [markdown]
# AKMCS class is used to generate new sample using 'U-function' as active learning function.

# %%
from UQpy.sampling.adaptive_kriging_functions import *
start_time = time.time()
learning_function = WeightedUFunction(weighted_u_stop=2)
a = AdaptiveKriging(runmodel_object=rmodel, surrogate=K, learning_nsamples=10 ** 3, n_add=1,
                    learning_function=learning_function, distributions=marginals, random_state=2)
a.run(nsamples=100, samples=x.samples)
elapsed_time = time.time() - start_time
# Out:
# /Users/dimitris/PycharmProjects/dimtsap/UQpy/src/UQpy/optimization/MinimizeOptimizer.py:24: OptimizeWarning: Unknown solver options: catol
#   return minimize(function, initial_guess, args=args,
#
#  Nonpositive definiteness in Cholesky factorization in formk;
#    refresh the lbfgs memory and restart the iteration.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.35794D+01    |proj g|=  9.99000D-01
#
# At iterate    1    f=  2.30021D+01    |proj g|=  6.56510D-01
#
# At iterate    2    f=  2.28806D+01    |proj g|=  8.89656D-01
#
# At iterate    3    f=  2.27085D+01    |proj g|=  9.18277D-01
#
# At iterate    4    f=  2.25341D+01    |proj g|=  2.83441D+00
#
# At iterate    5    f=  2.25252D+01    |proj g|=  3.61447D+00
#
# At iterate    6    f=  2.25252D+01    |proj g|=  3.65551D+00
#
# At iterate    7    f=  2.25252D+01    |proj g|=  3.65816D+00
# True
#
# At iterate    8    f=  2.25252D+01    |proj g|=  3.65833D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      8     20      9     0     0   3.658D+00   2.253D+01
#   F =   22.525200156646505
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# [ 3.85987238 13.07269314]
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.64883D+01    |proj g|=  2.58826D-02
#
# At iterate    1    f=  2.64876D+01    |proj g|=  2.50957D-02
#
# At iterate    2    f=  2.64695D+01    |proj g|=  8.52269D-03
#
# At iterate    3    f=  2.64557D+01    |proj g|=  1.11561D-02
#
# At iterate    4    f=  2.54951D+01    |proj g|=  4.16248D-02
#   ys=-1.089E+00  -gs= 1.420E-01 BFGS update SKIPPED
#
# At iterate    5    f=  2.54538D+01    |proj g|=  1.04544D-01
#
# At iterate    6    f=  2.54524D+01    |proj g|=  3.94070D-02
#
# At iterate    7    f=  2.54163D+01    |proj g|=  9.65136D-01
#
# At iterate    8    f=  2.53530D+01    |proj g|=  1.90941D-01
#   Positive dir derivative in projection
#   Using the backtracking step
#
# At iterate    9    f=  2.31438D+01    |proj g|=  7.86992D-01
#
# At iterate   10    f=  2.25948D+01    |proj g|=  6.52902D-01
# True
# [1.39512122e+00 5.00569780e+03]
# True
# [ 1.23077186 16.04073458]
#
# At iterate   11    f=  2.25184D+01    |proj g|=  5.60841D-01
#
# At iterate   12    f=  2.24944D+01    |proj g|=  4.20708D-01
#
# At iterate   13    f=  2.24223D+01    |proj g|=  3.10101D-01
#
# At iterate   14    f=  2.24048D+01    |proj g|=  2.80229D-01
#
# At iterate   15    f=  2.24037D+01    |proj g|=  7.56690D-02
#
# At iterate   16    f=  2.24036D+01    |proj g|=  6.58969D-03
#
# At iterate   17    f=  2.24036D+01    |proj g|=  1.44120D-03
#
# At iterate   18    f=  2.24036D+01    |proj g|=  2.62623D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     18     41     23     1     0   2.626D-04   2.240D+01
#   F =   22.403554311591925
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.64992D+01    |proj g|=  9.20006D-05
#
# At iterate    1    f=  2.64992D+01    |proj g|=  9.20118D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1      2      1     0     0   9.201D-05   2.650D+01
#   F =   26.499219332666691
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.70740D+01    |proj g|=  8.76188D-01
#
# At iterate    1    f=  2.66563D+01    |proj g|=  2.30895D-01
#
# At iterate    2    f=  2.65978D+01    |proj g|=  1.48783D-01
#
# At iterate    3    f=  2.65387D+01    |proj g|=  6.99284D-02
#
# At iterate    4    f=  2.65125D+01    |proj g|=  3.72430D-02
#
# At iterate    5    f=  2.64968D+01    |proj g|=  1.87411D-02
#
# At iterate    6    f=  2.64880D+01    |proj g|=  9.31158D-03
#
# At iterate    7    f=  2.64821D+01    |proj g|=  4.05628D-03
#
# At iterate    8    f=  2.64749D+01    |proj g|=  5.12086D-03
#
# At iterate    9    f=  2.56152D+01    |proj g|=  4.93924D-02
#   ys=-5.734E+00  -gs= 7.724E-02 BFGS update SKIPPED
#
# At iterate   10    f=  2.54761D+01    |proj g|=  3.84151D-02
#
# At iterate   11    f=  2.54157D+01    |proj g|=  8.42905D-01
#
# At iterate   12    f=  2.53590D+01    |proj g|=  5.98407D-02
#   Positive dir derivative in projection
#   Using the backtracking step
#
# At iterate   13    f=  2.30497D+01    |proj g|=  7.29825D-01
#   ys=-5.401E-01  -gs= 4.888E-01 BFGS update SKIPPED
#   Positive dir derivative in projection
#   Using the backtracking step
#
# At iterate   14    f=  2.29741D+01    |proj g|=  1.02052D+00
#
# At iterate   15    f=  2.26764D+01    |proj g|=  2.51677D+00
#
# At iterate   16    f=  2.26554D+01    |proj g|=  4.43105D+00
#   Positive dir derivative in projection
#   Using the backtracking step
#
# At iterate   17    f=  2.24430D+01    |proj g|=  1.56616D+00
#
# At iterate   18    f=  2.24370D+01    |proj g|=  3.27110D-01
#
# At iterate   19    f=  2.24074D+01    |proj g|=  2.72203D-01
#
# At iterate   20    f=  2.24041D+01    |proj g|=  1.15545D-01
#
# At iterate   21    f=  2.24036D+01    |proj g|=  5.23279D-02
#
# At iterate   22    f=  2.24036D+01    |proj g|=  2.12625D-02
#
# At iterate   23    f=  2.24036D+01    |proj g|=  4.67450D-04
# True
# [1.15312383e+00 5.82594114e+05]
# True
# [1.00623615e+00 1.68038315e+03]
#
# At iterate   24    f=  2.24036D+01    |proj g|=  1.16148D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     24     51     24     2     0   1.161D-04   2.240D+01
#   F =   22.403554306788219
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.64993D+01    |proj g|=  1.06344-233
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   1.063-233   2.650D+01
#   F =   26.499290519012895
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.64954D+01    |proj g|=  7.04263D-03
#
# At iterate    1    f=  2.64953D+01    |proj g|=  7.14375D-03
#   ys=-7.121E-07  -gs= 4.960E-05 BFGS update SKIPPED
#
# At iterate    2    f=  2.64696D+01    |proj g|=  4.57803D-05
#   ys=-5.933E-02  -gs= 7.131E-03 BFGS update SKIPPED
#
# At iterate    3    f=  2.54287D+01    |proj g|=  1.57246D+03
#   ys=-1.801E+06  -gs= 7.693E-02 BFGS update SKIPPED
#
# At iterate    4    f=  2.50580D+01    |proj g|=  1.37300D+03
#
# At iterate    5    f=  2.47457D+01    |proj g|=  5.85879D+02
#
# At iterate    6    f=  2.46228D+01    |proj g|=  2.92723D+02
#
# At iterate    7    f=  2.45084D+01    |proj g|=  1.10583D+02
#
# At iterate    8    f=  2.43543D+01    |proj g|=  8.40922D+01
#
# At iterate    9    f=  2.41188D+01    |proj g|=  5.97485D+01
#
# At iterate   10    f=  2.38757D+01    |proj g|=  2.98455D+01
#
# At iterate   11    f=  2.36400D+01    |proj g|=  1.89463D+01
#
# At iterate   12    f=  2.34000D+01    |proj g|=  1.11088D+01
#
# At iterate   13    f=  2.31594D+01    |proj g|=  7.00514D+00
#
# At iterate   14    f=  2.29195D+01    |proj g|=  4.03676D+00
#
# At iterate   15    f=  2.26963D+01    |proj g|=  2.64580D+00
#
# At iterate   16    f=  2.25271D+01    |proj g|=  1.39882D+00
#
# At iterate   17    f=  2.24388D+01    |proj g|=  1.21798D+00
#
# At iterate   18    f=  2.24074D+01    |proj g|=  3.25914D-01
#
# At iterate   19    f=  2.24040D+01    |proj g|=  1.06802D-01
#
# At iterate   20    f=  2.24036D+01    |proj g|=  1.83906D-02
#
# At iterate   21    f=  2.24036D+01    |proj g|=  2.95536D-03
#
# At iterate   22    f=  2.24036D+01    |proj g|=  6.73375D-04
# True
# At iterate   23    f=  2.24036D+01    |proj g|=  4.20025D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     23     53     23     3     0   4.200D-05   2.240D+01
#   F =   22.403554306549868
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
# [27.83984751  1.01548566]
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.63901D+01    |proj g|=  9.91088D-02
#
# At iterate    1    f=  2.63792D+01    |proj g|=  1.17980D-01
#   ys=-1.883E-03  -gs= 9.986E-03 BFGS update SKIPPED
#
# At iterate    2    f=  2.61284D+01    |proj g|=  2.97460D-02
#   ys=-3.399E-01  -gs= 1.095E-01 BFGS update SKIPPED
#
# At iterate    3    f=  2.61275D+01    |proj g|=  2.98013D-02
#   ys=-1.646E-06  -gs= 8.848E-04 BFGS update SKIPPED
#
# At iterate    4    f=  2.54287D+01    |proj g|=  1.57246D+03
#
# At iterate    5    f=  2.53506D+01    |proj g|=  1.88080D+03
#
# At iterate    6    f=  2.47499D+01    |proj g|=  7.24691D+02
#
# At iterate    7    f=  2.45779D+01    |proj g|=  4.10153D+02
#
# At iterate    8    f=  2.44426D+01    |proj g|=  1.75459D+02
#
# At iterate    9    f=  2.43403D+01    |proj g|=  6.53540D+01
#
# At iterate   10    f=  2.41745D+01    |proj g|=  6.29794D+01
#
# At iterate   11    f=  2.39257D+01    |proj g|=  3.87991D+01
#
# At iterate   12    f=  2.36907D+01    |proj g|=  2.32636D+01
#
# At iterate   13    f=  2.34497D+01    |proj g|=  1.46113D+01
#
# At iterate   14    f=  2.32092D+01    |proj g|=  8.60016D+00
#
# At iterate   15    f=  2.29671D+01    |proj g|=  5.40116D+00
#
# At iterate   16    f=  2.27383D+01    |proj g|=  2.90972D+00
#
# At iterate   17    f=  2.25558D+01    |proj g|=  1.85844D+00
#
# At iterate   18    f=  2.24507D+01    |proj g|=  8.98225D-01
#
# At iterate   19    f=  2.24106D+01    |proj g|=  4.68234D-01
#
# At iterate   20    f=  2.24038D+01    |proj g|=  6.25091D-02
#
# At iterate   21    f=  2.24036D+01    |proj g|=  1.03567D-02
#
# At iterate   22    f=  2.24036D+01    |proj g|=  3.43647D-04
# True
#
# [22.43716802  1.01484516]
# At iterate   23    f=  2.24036D+01    |proj g|=  4.38239D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     23     43     24     3     0   4.382D-06   2.240D+01
#   F =   22.403554306316003
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.62988D+01    |proj g|=  1.61107D-01
#
# At iterate    1    f=  2.62689D+01    |proj g|=  2.05169D-01
#   ys=-7.152E-03  -gs= 2.643E-02 BFGS update SKIPPED
#
# At iterate    2    f=  2.59387D+01    |proj g|=  4.06324D-02
#   ys=-3.234E-01  -gs= 1.774E-01 BFGS update SKIPPED
#
# At iterate    3    f=  2.59370D+01    |proj g|=  4.07167D-02
#   ys=-3.425E-06  -gs= 1.651E-03 BFGS update SKIPPED
#
# At iterate    4    f=  2.54158D+01    |proj g|=  8.11822D-01
#
# At iterate    5    f=  2.29843D+01    |proj g|=  6.47325D+00
#   ys=-2.019E+01  -gs= 2.055E-01 BFGS update SKIPPED
#
# At iterate    6    f=  2.29731D+01    |proj g|=  9.12750D-01
#
# At iterate    7    f=  2.29723D+01    |proj g|=  8.08252D-01
#
# At iterate    8    f=  2.24306D+01    |proj g|=  3.20402D-01
#
# At iterate    9    f=  2.24113D+01    |proj g|=  5.35656D-01
#
# At iterate   10    f=  2.24044D+01    |proj g|=  2.06973D-01
#
# At iterate   11    f=  2.24036D+01    |proj g|=  3.22632D-02
#
# At iterate   12    f=  2.24036D+01    |proj g|=  4.58868D-03
#
# At iterate   13    f=  2.24036D+01    |proj g|=  7.62551D-04
# True
# [1.51300369e+00 1.04464084e+04]
# True
# [1.05932313e+00 8.59316812e+03]
# True
# At iterate   14    f=  2.24036D+01    |proj g|=  1.08764D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     14     34     15     4     0   1.088D-05   2.240D+01
#   F =   22.403554306336240
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.64993D+01    |proj g|=  5.29643D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   5.296D-07   2.650D+01
#   F =   26.499290101072525
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.64993D+01    |proj g|=  5.12271D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   5.123D-06   2.650D+01
#   F =   26.499286480972032
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.17076D+01    |proj g|=  6.95134D-01
#
# At iterate    1    f=  2.16980D+01    |proj g|=  1.22093D+00
#
# At iterate    2    f=  2.16830D+01    |proj g|=  5.19556D-01
#
# At iterate    3    f=  2.16757D+01    |proj g|=  7.45977D-02
#
# At iterate    4    f=  2.16749D+01    |proj g|=  1.47882D-02
#
# At iterate    5    f=  2.16749D+01    |proj g|=  2.26438D-03
#
# At iterate    6    f=  2.16749D+01    |proj g|=  1.87469D-05
# True
#
# At iterate    7    f=  2.16749D+01    |proj g|=  1.16616D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      7      9      7     0     0   1.166D-08   2.167D+01
#   F =   21.674915789654648
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.03234D+01    |proj g|=  5.17573D-01
#
# At iterate    1    f=  2.03166D+01    |proj g|=  2.58129D-01
#
# At iterate    2    f=  2.03146D+01    |proj g|=  2.11820D-01
#
# At iterate    3    f=  2.03087D+01    |proj g|=  1.95453D-02
#
# At iterate    4    f=  2.03086D+01    |proj g|=  2.30354D-03
#
# At iterate    5    f=  2.03086D+01    |proj g|=  3.05767D-04
# True
#
# At iterate    6    f=  2.03086D+01    |proj g|=  5.86163D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6      9      7     0     0   5.862D-05   2.031D+01
#   F =   20.308614498574272
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# True
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.92903D+01    |proj g|=  4.55701D-01
#
# At iterate    1    f=  1.92855D+01    |proj g|=  2.85811D-01
#
# At iterate    2    f=  1.92819D+01    |proj g|=  2.79582D-01
#
# At iterate    3    f=  1.92767D+01    |proj g|=  5.32601D-02
#
# At iterate    4    f=  1.92766D+01    |proj g|=  6.74586D-03
#
# At iterate    5    f=  1.92766D+01    |proj g|=  2.91433D-04
#
# At iterate    6    f=  1.92766D+01    |proj g|=  3.08408D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6      9      7     0     0   3.084D-05   1.928D+01
#   F =   19.276641325058176
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.99485D+01    |proj g|=  3.99480D-01
#
# At iterate    1    f=  1.99218D+01    |proj g|=  1.22792D-01
#
# At iterate    2    f=  1.99216D+01    |proj g|=  2.56623D-02
#
# At iterate    3    f=  1.99216D+01    |proj g|=  4.86212D-03
#
# At iterate    4    f=  1.99216D+01    |proj g|=  3.81151D-05
# True
# At iterate    5    f=  1.99216D+01    |proj g|=  3.23124D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      9      6     0     0   3.231D-07   1.992D+01
#   F =   19.921617116704631
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.81365D+01    |proj g|=  4.00812D-01
#
# At iterate    1    f=  1.81344D+01    |proj g|=  1.87492D-01
#
# At iterate    2    f=  1.81339D+01    |proj g|=  1.55687D-01
#
# At iterate    3    f=  1.81320D+01    |proj g|=  5.03149D-02
#
# At iterate    4    f=  1.81320D+01    |proj g|=  4.01425D-03
# True
#
# At iterate    5    f=  1.81320D+01    |proj g|=  7.14055D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   7.141D-06   1.813D+01
#   F =   18.131953505505194
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# True
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.63975D+01    |proj g|=  4.62732D-01
#
# At iterate    1    f=  1.63952D+01    |proj g|=  2.04753D-01
#
# At iterate    2    f=  1.63946D+01    |proj g|=  1.88602D-01
#
# At iterate    3    f=  1.63925D+01    |proj g|=  8.63080D-02
#
# At iterate    4    f=  1.63924D+01    |proj g|=  2.98498D-03
#
# At iterate    5    f=  1.63924D+01    |proj g|=  2.59712D-05
#
# At iterate    6    f=  1.63924D+01    |proj g|=  3.56599D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6      9      7     0     0   3.566D-07   1.639D+01
#   F =   16.392437629914781
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.45769D+01    |proj g|=  2.28367D-01
#
# At iterate    1    f=  1.45758D+01    |proj g|=  2.03416D-01
#
# At iterate    2    f=  1.45751D+01    |proj g|=  4.02935D-02
#
# At iterate    3    f=  1.45751D+01    |proj g|=  1.79344D-03
# True
#
# At iterate    4    f=  1.45751D+01    |proj g|=  2.22943D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      7      4     0     0   2.229D-05   1.458D+01
#   F =   14.575101812856698
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.43187D+01    |proj g|=  2.51633D-01
#
# At iterate    1    f=  1.43174D+01    |proj g|=  1.42100D-01
#
# At iterate    2    f=  1.43172D+01    |proj g|=  1.17413D-01
#
# At iterate    3    f=  1.43165D+01    |proj g|=  3.92819D-03
#
# At iterate    4    f=  1.43165D+01    |proj g|=  1.12890D-04
# True
#
# At iterate    5    f=  1.43165D+01    |proj g|=  9.78395D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   9.784D-07   1.432D+01
#   F =   14.316541995935168
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# True
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.46117D+01    |proj g|=  8.74489D-01
#
# At iterate    1    f=  1.46083D+01    |proj g|=  1.97955D-01
#
# At iterate    2    f=  1.46075D+01    |proj g|=  2.10427D-01
#
# At iterate    3    f=  1.46069D+01    |proj g|=  2.38937D-01
#
# At iterate    4    f=  1.46062D+01    |proj g|=  1.29650D-01
#
# At iterate    5    f=  1.46061D+01    |proj g|=  1.12953D-02
#
# At iterate    6    f=  1.46061D+01    |proj g|=  1.98494D-04
#
# At iterate    7    f=  1.46061D+01    |proj g|=  2.11482D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      7     10      8     0     0   2.115D-05   1.461D+01
#   F =   14.606060665738109
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.50740D+01    |proj g|=  2.56709D-01
#
# At iterate    1    f=  1.50726D+01    |proj g|=  1.89460D-01
#
# At iterate    2    f=  1.50714D+01    |proj g|=  1.87521D-01
#
# At iterate    3    f=  1.50682D+01    |proj g|=  3.40275D-02
#
# At iterate    4    f=  1.50682D+01    |proj g|=  2.83985D-03
#
# At iterate    5    f=  1.50682D+01    |proj g|=  8.72868D-05
# True
#
# At iterate    6    f=  1.50682D+01    |proj g|=  7.05124D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6      9      7     0     0   7.051D-06   1.507D+01
#   F =   15.068228628042164
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.69850D+01    |proj g|=  9.84857D+00
#
# At iterate    1    f=  1.69041D+01    |proj g|=  6.61502D+00
#
# At iterate    2    f=  1.66719D+01    |proj g|=  2.59730D+00
#
# At iterate    3    f=  1.66335D+01    |proj g|=  5.69058D-01
#
# At iterate    4    f=  1.66302D+01    |proj g|=  3.46622D-01
#
# At iterate    5    f=  1.66281D+01    |proj g|=  2.84393D-01
#
# At iterate    6    f=  1.66270D+01    |proj g|=  5.26387D-03
#
# At iterate    7    f=  1.66270D+01    |proj g|=  6.75833D-04
# True
#
# At iterate    8    f=  1.66270D+01    |proj g|=  2.82128D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      8     12      9     0     0   2.821D-06   1.663D+01
#   F =   16.627032676297002
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# True
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.51812D+01    |proj g|=  2.90921D-01
#
# At iterate    1    f=  1.51804D+01    |proj g|=  2.44598D-01
#
# At iterate    2    f=  1.51798D+01    |proj g|=  1.85987D-01
#
# At iterate    3    f=  1.51793D+01    |proj g|=  1.02475D-02
#
# At iterate    4    f=  1.51793D+01    |proj g|=  3.88486D-04
#
# At iterate    5    f=  1.51793D+01    |proj g|=  2.03175D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   2.032D-06   1.518D+01
#   F =   15.179294906104776
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.76649D+01    |proj g|=  9.71251D+00
#
# At iterate    1    f=  1.69736D+01    |proj g|=  4.58697D-01
#
# At iterate    2    f=  1.68516D+01    |proj g|=  4.22551D-01
#
# At iterate    3    f=  1.68063D+01    |proj g|=  1.70467D+00
#
# At iterate    4    f=  1.67960D+01    |proj g|=  9.28208D-02
#
# At iterate    5    f=  1.67959D+01    |proj g|=  1.62123D-02
#
# At iterate    6    f=  1.67958D+01    |proj g|=  1.71760D-04
# True
#
# At iterate    7    f=  1.67958D+01    |proj g|=  1.83742D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      7     11      8     0     0   1.837D-07   1.680D+01
#   F =   16.795849931838173
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.69851D+01    |proj g|=  3.69959D-01
# True
#
# At iterate    1    f=  1.69842D+01    |proj g|=  1.37193D-01
#
# At iterate    2    f=  1.69841D+01    |proj g|=  8.42001D-02
#
# At iterate    3    f=  1.69838D+01    |proj g|=  4.43669D-02
#
# At iterate    4    f=  1.69837D+01    |proj g|=  6.28252D-03
#
# At iterate    5    f=  1.69837D+01    |proj g|=  1.84153D-04
#
# At iterate    6    f=  1.69837D+01    |proj g|=  4.66025D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6      9      7     0     0   4.660D-06   1.698D+01
#   F =   16.983745463223325
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.74403D+01    |proj g|=  1.23699D-01
#
# At iterate    1    f=  1.74401D+01    |proj g|=  1.23407D-01
#
# At iterate    2    f=  1.74400D+01    |proj g|=  7.50765D-02
#
# At iterate    3    f=  1.74399D+01    |proj g|=  1.05286D-03
# True
# At iterate    4    f=  1.74399D+01    |proj g|=  1.11765D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      7      4     0     0   1.118D-05   1.744D+01
#   F =   17.439923773928747
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.78480D+01    |proj g|=  3.41362D-01
#
# At iterate    1    f=  1.78422D+01    |proj g|=  1.82928D-01
#
# At iterate    2    f=  1.78409D+01    |proj g|=  4.05008D-01
#
# At iterate    3    f=  1.78403D+01    |proj g|=  2.11307D-02
#
# At iterate    4    f=  1.78403D+01    |proj g|=  3.28348D-04
# True
#
# At iterate    5    f=  1.78403D+01    |proj g|=  2.04676D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   2.047D-05   1.784D+01
#   F =   17.840309898779189
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# True
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.81198D+01    |proj g|=  3.18054D-01
#
# At iterate    1    f=  1.81190D+01    |proj g|=  1.77205D-01
#
# At iterate    2    f=  1.81183D+01    |proj g|=  1.75850D-01
#
# At iterate    3    f=  1.81173D+01    |proj g|=  1.11208D-02
#
# At iterate    4    f=  1.81173D+01    |proj g|=  4.64913D-04
#
# At iterate    5    f=  1.81173D+01    |proj g|=  8.08147D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   8.081D-06   1.812D+01
#   F =   18.117301751843350
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.77995D+01    |proj g|=  2.54249D-01
#
# At iterate    1    f=  1.77985D+01    |proj g|=  1.56697D-01
#
# At iterate    2    f=  1.77983D+01    |proj g|=  1.24195D-01
#
# At iterate    3    f=  1.77980D+01    |proj g|=  2.40275D-03
#
# At iterate    4    f=  1.77980D+01    |proj g|=  4.43682D-05
# True
#
# At iterate    5    f=  1.77980D+01    |proj g|=  3.41966D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   3.420D-07   1.780D+01
#   F =   17.797982828319249
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.87630D+01    |proj g|=  1.32715D+00
#
# At iterate    1    f=  1.87611D+01    |proj g|=  5.09280D-01
#
# At iterate    2    f=  1.87584D+01    |proj g|=  4.48464D-02
#
# At iterate    3    f=  1.87584D+01    |proj g|=  2.01554D-02
#
# At iterate    4    f=  1.87584D+01    |proj g|=  1.27653D-02
#
# At iterate    5    f=  1.87584D+01    |proj g|=  9.88098D-03
#
# At iterate    6    f=  1.87584D+01    |proj g|=  1.71600D-05
# True
#
# At iterate    7    f=  1.87584D+01    |proj g|=  1.67645D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      7     10      8     0     0   1.676D-07   1.876D+01
#   F =   18.758426459241143
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.91408D+01    |proj g|=  1.72728D-01
#
# At iterate    1    f=  1.91388D+01    |proj g|=  3.04221D-01
#
# At iterate    2    f=  1.91382D+01    |proj g|=  3.02800D-01
#
# At iterate    3    f=  1.91360D+01    |proj g|=  3.38163D-02
#
# At iterate    4    f=  1.91360D+01    |proj g|=  2.03477D-03
# True
#
# At iterate    5    f=  1.91360D+01    |proj g|=  6.15604D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   6.156D-06   1.914D+01
#   F =   19.136034984620842
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.90631D+01    |proj g|=  3.18323D-01
#
# At iterate    1    f=  1.90627D+01    |proj g|=  1.34151D-01
#
# At iterate    2    f=  1.90626D+01    |proj g|=  9.12147D-02
#
# At iterate    3    f=  1.90624D+01    |proj g|=  4.53321D-02
#
# At iterate    4    f=  1.90624D+01    |proj g|=  6.13941D-03
#
# At iterate    5    f=  1.90623D+01    |proj g|=  1.71715D-04
# True
#
# At iterate    6    f=  1.90623D+01    |proj g|=  3.95374D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6      9      7     0     0   3.954D-06   1.906D+01
#   F =   19.062349922245737
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# True
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.74231D+01    |proj g|=  1.61645D-01
#
# At iterate    1    f=  1.74227D+01    |proj g|=  1.01165D-01
#
# At iterate    2    f=  1.74226D+01    |proj g|=  7.64835D-02
#
# At iterate    3    f=  1.74225D+01    |proj g|=  1.26703D-02
#
# At iterate    4    f=  1.74225D+01    |proj g|=  1.53994D-05
#
# At iterate    5    f=  1.74225D+01    |proj g|=  9.31062D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   9.311D-08   1.742D+01
#   F =   17.422463271990665
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.78026D+01    |proj g|=  7.04544D-01
#
# At iterate    1    f=  1.78016D+01    |proj g|=  2.34313D-01
#
# At iterate    2    f=  1.78015D+01    |proj g|=  2.02383D-01
#
# At iterate    3    f=  1.78009D+01    |proj g|=  4.53371D-03
#
# At iterate    4    f=  1.78009D+01    |proj g|=  1.54267D-04
# True
#
# At iterate    5    f=  1.78009D+01    |proj g|=  4.95535D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      5     0     0   4.955D-06   1.780D+01
#   F =   17.800903401617724
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.78873D+01    |proj g|=  1.64047D-01
# True
#
# At iterate    1    f=  1.78868D+01    |proj g|=  1.90401D-01
#
# At iterate    2    f=  1.78867D+01    |proj g|=  1.78209D-01
#
# At iterate    3    f=  1.78863D+01    |proj g|=  9.81307D-03
#
# At iterate    4    f=  1.78863D+01    |proj g|=  2.91178D-04
#
# At iterate    5    f=  1.78863D+01    |proj g|=  2.98297D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   2.983D-07   1.789D+01
#   F =   17.886256142734759
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.74039D+01    |proj g|=  3.37936D-01
#
# At iterate    1    f=  1.74024D+01    |proj g|=  1.83707D-01
#
# At iterate    2    f=  1.74019D+01    |proj g|=  1.57127D-01
#
# At iterate    3    f=  1.74010D+01    |proj g|=  9.27451D-03
#
# At iterate    4    f=  1.74010D+01    |proj g|=  3.21008D-04
# True
#
# At iterate    5    f=  1.74010D+01    |proj g|=  5.15664D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   5.157D-06   1.740D+01
#   F =   17.400956425308600
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.79140D+01    |proj g|=  1.53475D-01
#
# At iterate    1    f=  1.79134D+01    |proj g|=  2.26664D-01
#
# At iterate    2    f=  1.79133D+01    |proj g|=  2.13164D-01
# True
#
# At iterate    3    f=  1.79127D+01    |proj g|=  1.33593D-02
#
# At iterate    4    f=  1.79127D+01    |proj g|=  4.46802D-04
#
# At iterate    5    f=  1.79127D+01    |proj g|=  4.78563D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   4.786D-07   1.791D+01
#   F =   17.912726448708341
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.56294D+01    |proj g|=  1.49012D-01
#
# At iterate    1    f=  1.56290D+01    |proj g|=  1.12202D-01
#
# At iterate    2    f=  1.56290D+01    |proj g|=  8.33035D-02
#
# At iterate    3    f=  1.56288D+01    |proj g|=  1.08410D-02
#
# At iterate    4    f=  1.56288D+01    |proj g|=  3.58583D-05
# True
#
# At iterate    5    f=  1.56288D+01    |proj g|=  9.43942D-09
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   9.439D-09   1.563D+01
#   F =   15.628838133129996
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.55399D+01    |proj g|=  1.59757D-01
#
# ...
#   F =   5.1935771700274955
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.52461D+00    |proj g|=  1.62134D-01
#
# At iterate    1    f=  4.52457D+00    |proj g|=  8.25433D-02
#
# At iterate    2    f=  4.52455D+00    |proj g|=  6.82738D-02
#
# At iterate    3    f=  4.52453D+00    |proj g|=  7.92626D-04
# True
#
# At iterate    4    f=  4.52453D+00    |proj g|=  3.98423D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      7      5     0     0   3.984D-06   4.525D+00
#   F =   4.5245332027819387
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.42863D+00    |proj g|=  3.88447D-01
#
# At iterate    1    f=  4.42843D+00    |proj g|=  8.47456D-02
#
# At iterate    2    f=  4.42842D+00    |proj g|=  3.39457D-02
#
# At iterate    3    f=  4.42842D+00    |proj g|=  3.45830D-02
#
# At iterate    4    f=  4.42841D+00    |proj g|=  1.17852D-02
#
# At iterate    5    f=  4.42841D+00    |proj g|=  8.47719D-05
# True
#
# At iterate    6    f=  4.42841D+00    |proj g|=  4.75446D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6      9      7     0     0   4.754D-06   4.428D+00
#   F =   4.4284107474998962
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.75927D+00    |proj g|=  1.61789D-01
#
# At iterate    1    f=  3.75920D+00    |proj g|=  5.02819D-02
#
# At iterate    2    f=  3.75919D+00    |proj g|=  4.80461D-02
#
# At iterate    3    f=  3.75918D+00    |proj g|=  4.39141D-03
#
# At iterate    4    f=  3.75918D+00    |proj g|=  1.43787D-05
# True
#
# At iterate    5    f=  3.75918D+00    |proj g|=  3.19338D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   3.193D-08   3.759D+00
#   F =   3.7591764253000122
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.23944D+00    |proj g|=  2.23382D+00
# At iterate    1    f=  4.23524D+00    |proj g|=  2.34784D+00
#
# At iterate    2    f=  4.22849D+00    |proj g|=  4.06851D-01
#
# At iterate    3    f=  4.22828D+00    |proj g|=  1.41526D-01
#
# At iterate    4    f=  4.22820D+00    |proj g|=  2.36173D-02
#
# At iterate    5    f=  4.22820D+00    |proj g|=  2.04267D-03
# True
#
# At iterate    6    f=  4.22820D+00    |proj g|=  1.39327D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6      9      7     0     0   1.393D-05   4.228D+00
#   F =   4.2282002936733107
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.87368D+00    |proj g|=  2.77226D+00
#
# At iterate    1    f=  4.86499D+00    |proj g|=  1.36324D+00
#
# At iterate    2    f=  4.86220D+00    |proj g|=  9.58043D-01
#
# At iterate    3    f=  4.85868D+00    |proj g|=  2.91131D-02
#
# At iterate    4    f=  4.85867D+00    |proj g|=  1.03721D-03
# True
#
# At iterate    5    f=  4.85867D+00    |proj g|=  3.69767D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      5     0     0   3.698D-05   4.859D+00
#   F =   4.8586699780924363
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.94558D+00    |proj g|=  4.77193D-01
#
# At iterate    1    f=  3.94479D+00    |proj g|=  1.52779D-01
#
# At iterate    2    f=  3.94469D+00    |proj g|=  1.43273D-01
#
# At iterate    3    f=  3.94461D+00    |proj g|=  1.17861D-02
#
# At iterate    4    f=  3.94461D+00    |proj g|=  5.25649D-05
# True
#
# At iterate    5    f=  3.94461D+00    |proj g|=  4.11155D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   4.112D-08   3.945D+00
#   F =   3.9446135089386729
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.06755D+00    |proj g|=  1.87512D-01
#
# At iterate    1    f=  4.06751D+00    |proj g|=  1.25091D-01
#
# At iterate    2    f=  4.06749D+00    |proj g|=  7.14693D-02
#
# At iterate    3    f=  4.06747D+00    |proj g|=  2.39428D-02
#
# At iterate    4    f=  4.06747D+00    |proj g|=  4.88398D-03
# True
#
# At iterate    5    f=  4.06747D+00    |proj g|=  1.74798D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      7      5     0     0   1.748D-06   4.067D+00
#   F =   4.0674688403699832
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.10371D+00    |proj g|=  2.16457D-01
#
# At iterate    1    f=  1.10363D+00    |proj g|=  7.30096D-02
#
# At iterate    2    f=  1.10362D+00    |proj g|=  5.63691D-02
#
# At iterate    3    f=  1.10360D+00    |proj g|=  1.35902D-04
# True
#
# At iterate    4    f=  1.10360D+00    |proj g|=  3.29542D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      7      4     0     0   3.295D-07   1.104D+00
#   F =   1.1035956661216062
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.02010D+00    |proj g|=  4.52249D-01
#
# At iterate    1    f=  1.01881D+00    |proj g|=  2.78058D-01
#
# At iterate    2    f=  1.01784D+00    |proj g|=  1.89768D-01
#
# At iterate    3    f=  1.01694D+00    |proj g|=  1.40405D-02
#
# At iterate    4    f=  1.01694D+00    |proj g|=  3.54721D-04
# True
#
# At iterate    5    f=  1.01694D+00    |proj g|=  1.07731D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   1.077D-06   1.017D+00
#   F =   1.0169352722509188
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.04402D-02    |proj g|=  6.11962D-01
#
# At iterate    1    f=  9.00090D-02    |proj g|=  1.70147D-01
#
# At iterate    2    f=  8.99749D-02    |proj g|=  3.00629D-02
#
# At iterate    3    f=  8.99729D-02    |proj g|=  2.72193D-02
#
# At iterate    4    f=  8.99696D-02    |proj g|=  1.88275D-03
#
# At iterate    5    f=  8.99696D-02    |proj g|=  1.08398D-05
# True
#
# At iterate    6    f=  8.99696D-02    |proj g|=  1.00731D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6      9      7     0     0   1.007D-07   8.997D-02
#   F =   8.9969560185693354E-002
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.09409D+00    |proj g|=  7.53489D-01
#
# At iterate    1    f= -1.09473D+00    |proj g|=  1.71723D-01
#
# At iterate    2    f= -1.09484D+00    |proj g|=  9.26507D-02
#
# At iterate    3    f= -1.09486D+00    |proj g|=  8.45315D-02
#
# At iterate    4    f= -1.09489D+00    |proj g|=  1.19042D-02
#
# At iterate    5    f= -1.09489D+00    |proj g|=  2.40656D-04
# True
#
# At iterate    6    f= -1.09489D+00    |proj g|=  6.38374D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6      9      7     0     0   6.384D-06  -1.095D+00
#   F =  -1.0948887930497051
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.79717D+00    |proj g|=  5.05509D-01
#
# At iterate    1    f= -1.79751D+00    |proj g|=  1.40234D-01
#
# At iterate    2    f= -1.79753D+00    |proj g|=  5.44509D-02
#
# At iterate    3    f= -1.79754D+00    |proj g|=  5.12592D-02
#
# At iterate    4    f= -1.79755D+00    |proj g|=  1.20401D-02
#
# At iterate    5    f= -1.79755D+00    |proj g|=  2.86040D-04
# True
#
# At iterate    6    f= -1.79755D+00    |proj g|=  1.26240D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6      9      7     0     0   1.262D-05  -1.798D+00
#   F =  -1.7975510461023703
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -3.32437D+00    |proj g|=  2.11547D-01
#
# At iterate    1    f= -3.32441D+00    |proj g|=  5.01528D-02
#
# At iterate    2    f= -3.32442D+00    |proj g|=  1.30317D-02
#
# At iterate    3    f= -3.32442D+00    |proj g|=  8.63160D-03
#
# At iterate    4    f= -3.32442D+00    |proj g|=  1.30544D-03
# True
#
# At iterate    5    f= -3.32442D+00    |proj g|=  1.17667D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      7      5     0     0   1.177D-06  -3.324D+00
#   F =  -3.3244201822763557
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.98448D+00    |proj g|=  1.70005D+00
#
# At iterate    1    f= -2.98760D+00    |proj g|=  7.09792D-01
#
# At iterate    2    f= -2.98840D+00    |proj g|=  5.21318D-01
#
# At iterate    3    f= -2.98940D+00    |proj g|=  1.01529D-02
#
# At iterate    4    f= -2.98940D+00    |proj g|=  2.16986D-04
# True
#
# At iterate    5    f= -2.98940D+00    |proj g|=  7.51489D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      5     0     0   7.515D-06  -2.989D+00
#   F =  -2.9893961414760213
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL

# %%
time.strftime("%H:%M:%S", time.gmtime(elapsed_time))
g = a.surrogate.predict(a.learning_set, False)
n_ = a.learning_set.shape[0] + len(a.qoi)
pf = (sum(g < 0) + sum(np.array(a.qoi) < 0)) / n_
print('Time: ', elapsed_time)
print('Function evaluation: ', a.samples.shape[0])
print('Probability of failure: ', pf)
# Out:
# Time:  2.8595240116119385
# Function evaluation:  100
# Probability of failure:  [0.60181818]

# %% [markdown]
# This figure shows the location of new samples generated using active learning function.

# %%
num = 50
x1 = np.linspace(-7, 7, num)
x2 = np.linspace(-7, 7, num)
x1v, x2v = np.meshgrid(x1, x2)
y = np.zeros([num, num])
y_act = np.zeros([num, num])
mse = np.zeros([num, num])
for i in range(num):
    for j in range(num):
        xa = marginals[0].cdf(np.atleast_2d(x1v[i, j]))
        ya = marginals[1].cdf(np.atleast_2d(x2v[i, j]))
        y[i, j] = a.surrogate.predict(np.hstack([xa, ya]))
        y_act[i, j] = series(np.array([[x1v[i, j], x2v[i, j]]]))

fig, ax = plt.subplots()
kr_a = ax.contour(x1v, x2v, y_act, levels=[0], colors='Black')

# Plot for scattered data
nd = x.nsamples
ID1 = ax.scatter(a.samples[nd:, 0], a.samples[nd:, 1], color='Grey', label='New samples')
ID = ax.scatter(x.samples[:nd, 0], x.samples[:nd, 1], color='Red', label='Initial samples')
plt.legend(handles=[ID1, ID])
plt.show()

# %% [markdown]
# ## User-define Learning function

# %%
class UserLearningFunction(LearningFunction):

    def __init__(self, u_stop: int = 2):
        self.u_stop = u_stop

    def evaluate_function(self, distributions, n_add, surrogate, population, qoi=None, samples=None):
        # AKMS class use these inputs to compute the learning function

        g, sig = surrogate.predict(population, True)

        # Remove the inconsistency in the shape of 'g' and 'sig' array
        g = g.reshape([population.shape[0], 1])
        sig = sig.reshape([population.shape[0], 1])

        u = abs(g) / sig
        rows = u[:, 0].argsort()[:n_add]

        indicator = False
        if min(u[:, 0]) >= self.u_stop:
            indicator = True

        return population[rows, :], u[rows, 0], indicator

# %% [markdown]
# Creating new instances of Kriging and RunModel class.

# %%
K1 = Kriging(regression_model=Linear(), correlation_model=Exponential(), optimizer=optimizer,
             correlation_model_parameters=[1, 1], optimizations_number=10)
rmodel1 = RunModel(model_script='series.py', vec=False)

# %% [markdown]
# Executing AKMCS with the user-defined learning function.

# %%
start_time = time.time()
ak = AdaptiveKriging(runmodel_object=rmodel1, samples=x.samples, surrogate=K1, learning_nsamples=10 ** 3,
                     n_add=1, learning_function=UserLearningFunction(), distributions=marginals, random_state=3)
ak.run(nsamples=100)
elapsed_time = time.time() - start_time
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.35794D+01    |proj g|=  9.99000D-01
#
# At iterate    1    f=  2.30021D+01    |proj g|=  6.56510D-01
#
# At iterate    2    f=  2.28806D+01    |proj g|=  8.89656D-01
#
# At iterate    3    f=  2.27085D+01    |proj g|=  9.18277D-01
#
# At iterate    4    f=  2.25341D+01    |proj g|=  2.83441D+00
#
# At iterate    5    f=  2.25252D+01    |proj g|=  3.61447D+00
#
# At iterate    6    f=  2.25252D+01    |proj g|=  3.65551D+00
#
# At iterate    7    f=  2.25252D+01    |proj g|=  3.65816D+00
# True
#
# [1.45497625e+04 1.02924770e+00]
# True
# [1.19307452e+06 1.08608998e+01]
# At iterate    8    f=  2.25252D+01    |proj g|=  3.65833D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      8     20      9     0     0   3.658D+00   2.253D+01
#   F =   22.525200156646505
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.64993D+01    |proj g|=  2.50897-156
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments eTrue
# [   93.66276076 33362.52351803]
# xplored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   2.509-156   2.650D+01
#   F =   26.499290519012895
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.64993D+01    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = finalTrue
# [1.93473818e+00 1.40845842e+06]
# True function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   0.000D+00   2.650D+01
#   F =   26.499290519012895
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.64993D+01    |proj g|=  8.43342D-67
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   8.433D-67   2.650D+01
#   F =   26.499290519012895
#
# CONVE
# RGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.64993D+01    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   0.000D+00   2.650D+01
#   F =   26.499290519012895
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# [17.8894594   1.29777967]
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.62276D+01    |proj g|=  1.63961D-01
#
# At iterate    1    f=  2.61968D+01    |proj g|=  2.01927D-01
#   ys=-6.309E-03  -gs= 2.780E-02 BFGS update SKIPPED
#
# At iterate    2    f=  2.57295D+01    |proj g|=  4.87859D-02
#   ys=-4.053E-01  -gs= 2.349E-01 BFGS update SKIPPED
#
# At iterate    3    f=  2.54182D+01    |proj g|=  6.34308D-01
#
# At iterate    4    f=  2.24500D+01    |proj g|=  2.10933D+00
#   ys=-1.084E+01  -gs= 2.475E-01 BFGS update SKIPPED
#
# At iterate    5    f=  2.24096D+01    |proj g|=  2.74185D-01
#
# At iterate    6    f=  2.24036D+01    |proj g|=  8.52829D-02
#
# At iterate    7    f=  2.24036D+01    |proj g|=  1.81849D-02
#
# At iterate    8    f=  2.24036D+01    |proj g|=  1.12770D-02
#
# At iterate    9    f=  2.24036D+01    |proj g|=  1.43036D-03
# True
#
# [11297.47554431 81862.99406869]
# At iterate   10    f=  2.24036D+01    |proj g|=  1.07234D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     10     29     10     3     0   1.072D-06   2.240D+01
#   F =   22.403554306315755
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# True
# [392.10877135   1.00315517]
# True
# [10.43697388 44.37954819]
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.64993D+01    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   0.000D+00   2.650D+01
#   F =   26.499290519012895
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.64993D+01    |proj g|=  8.33545D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   8.335D-06   2.650D+01
#   F =   26.499303539000575
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.64981D+01    |proj g|=  3.22432D-04
#
# At iterate    1    f=  2.64981D+01    |proj g|=  3.22456D-04
#   ys=-7.990E-12  -gs= 1.051E-07 BFGS update SKIPPED
#
# At iterate    2    f=  2.64965D+01    |proj g|=  1.46583D-04
#
# At iterate    3    f=  2.64965D+01    |proj g|=  5.76874D-05
#
# At iterate    4    f=  2.64964D+01    |proj g|=  1.51173D-04
#
# At iterate    5    f=  2.55990D+01    |proj g|=  3.76640D-01
#   ys=-1.506E+01  -gs= 2.161E-03 BFGS update SKIPPED
#
# At iterate    6    f=  2.25706D+01    |proj g|=  2.61564D+00
#   ys=-2.868E-02  -gs= 1.375E+00 BFGS update SKIPPED
#
# At iterate    7    f=  2.25212D+01    |proj g|=  4.09584D-01
#
# At iterate    8    f=  2.24697D+01    |proj g|=  3.60158D-01
#
# At iterate    9    f=  2.24539D+01    |proj g|=  5.82142D-01
#
# At iterate   10    f=  2.24406D+01    |proj g|=  5.52609D-01
#
# At iterate   11    f=  2.24087D+01    |proj g|=  2.64780D-01
#
# At iterate   12    f=  2.24055D+01    |proj g|=  2.49744D-01
#
# At iterate   13    f=  2.24036D+01    |proj g|=  4.89263D-02
#
# At iterate   14    f=  2.24036D+01    |proj g|=  3.61157D-03
#
# At iterate   15    f=  2.24036D+01    |proj g|=  2.56576D-04
# True
# At iterate   16    f=  2.24036D+01    |proj g|=  4.49007D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     16     43     20     3     0   4.490D-05   2.240D+01
#   F =   22.403554306337881
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
# [2334722.77292946   56239.46478194]
# True
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.64993D+01    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   0.000D+00   2.650D+01
#   F =   26.499290519012895
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.31021D+01    |proj g|=  4.13350D-01
#
# At iterate    1    f=  2.30977D+01    |proj g|=  2.53958D-01
#
# At iterate    2    f=  2.30812D+01    |proj g|=  2.26626D-01
#
# At iterate    3    f=  2.30755D+01    |proj g|=  2.33317D-01
#
# At iterate    4    f=  2.30750D+01    |proj g|=  4.95934D-02
#
# At iterate    5    f=  2.30750D+01    |proj g|=  2.00354D-03
#
# At iterate    6    f=  2.30750D+01    |proj g|=  6.02014D-04
# True
# At iterate    7    f=  2.30750D+01    |proj g|=  1.91731D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      7     11      8     0     0   1.917D-06   2.307D+01
#   F =   23.074977044696311
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.38431D+01    |proj g|=  4.18444D-01
#
# At iterate    1    f=  2.38358D+01    |proj g|=  3.09464D-01
#
# At iterate    2    f=  2.37840D+01    |proj g|=  2.70443D-01
#
# At iterate    3    f=  2.37336D+01    |proj g|=  2.10348D-01
#
# At iterate    4    f=  2.37269D+01    |proj g|=  3.31215D-01
#
# At iterate    5    f=  2.37244D+01    |proj g|=  1.29356D-01
#
# At iterate    6    f=  2.37243D+01    |proj g|=  1.17964D-01
#
# At iterate    7    f=  2.37242D+01    |proj g|=  2.49618D-02
#
# At iterate    8    f=  2.37242D+01    |proj g|=  2.32910D-03
#
# At iterate    9    f=  2.37242D+01    |proj g|=  3.71164D-04
# True
# At iterate   10    f=  2.37242D+01    |proj g|=  1.55019D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     10     15     11     0     0   1.550D-05   2.372D+01
#   F =   23.724242589620332
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#
# True
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.95023D+01    |proj g|=  1.31893D+01
#
# At iterate    1    f=  2.80024D+01    |proj g|=  9.81711D-01
#
# At iterate    2    f=  2.74946D+01    |proj g|=  1.15410D+00
#
# At iterate    3    f=  2.73707D+01    |proj g|=  3.44126D+00
#
# At iterate    4    f=  2.72466D+01    |proj g|=  6.56447D-01
#
# At iterate    5    f=  2.72365D+01    |proj g|=  4.22204D-01
#
# At iterate    6    f=  2.72187D+01    |proj g|=  1.08459D-01
#
# At iterate    7    f=  2.72180D+01    |proj g|=  1.56847D-02
#
# At iterate    8    f=  2.72180D+01    |proj g|=  6.22882D-03
#
# At iterate    9    f=  2.72180D+01    |proj g|=  1.51166D-03
#
# At iterate   10    f=  2.72180D+01    |proj g|=  2.16171D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     10     16     10     0     0   2.162D-06   2.722D+01
#   F =   27.217950175971207
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.75772D+01    |proj g|=  3.91595D-01
#
# At iterate    1    f=  2.75719D+01    |proj g|=  1.38510D-01
#
# At iterate    2    f=  2.75711D+01    |proj g|=  1.26779D-01
#
# At iterate    3    f=  2.75696D+01    |proj g|=  1.73680D-02
#
# At iterate    4    f=  2.75696D+01    |proj g|=  1.04231D-03
# True
#
# At iterate    5    f=  2.75696D+01    |proj g|=  3.66444D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   3.664D-06   2.757D+01
#   F =   27.569608112016802
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.88970D+01    |proj g|=  8.76429D-01
#
# At iterate    1    f=  2.88887D+01    |proj g|=  4.07734D-01
#
# At iterate    2    f=  2.88836D+01    |proj g|=  1.01929D-01
#
# True
#  Nonpositive definiteness in Cholesky factorization in formk;
#    refresh the lbfgs memory and restart the iteration.
# True
# At iterate    3    f=  2.88833D+01    |proj g|=  5.85552D-02
#
# At iterate    4    f=  2.88829D+01    |proj g|=  4.22630D-02
#
# At iterate    5    f=  2.88828D+01    |proj g|=  3.88273D-03
#
# At iterate    6    f=  2.88828D+01    |proj g|=  2.00038D-04
#
# At iterate    7    f=  2.88828D+01    |proj g|=  1.54809D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      7      9      7     0     0   1.548D-05   2.888D+01
#   F =   28.882849245936008
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.97351D+01    |proj g|=  3.05493D-01
#
# At iterate    1    f=  2.97334D+01    |proj g|=  4.98512D-02
#
# At iterate    2    f=  2.97333D+01    |proj g|=  4.28156D-02
#
# At iterate    3    f=  2.97332D+01    |proj g|=  9.38760D-04
#
# At iterate    4    f=  2.97332D+01    |proj g|=  1.79556D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      7      4     0     0   1.796D-05   2.973D+01
#   F =   29.733150815784626
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.99190D+01    |proj g|=  3.41034D-01
#
# At iterate    1    f=  2.99154D+01    |proj g|=  1.62943D-01
#
# At iterate    2    f=  2.99145D+01    |proj g|=  1.09511D-01
#
# At iterate    3    f=  2.99133D+01    |proj g|=  5.89738D-03
#
# At iterate    4    f=  2.99133D+01    |proj g|=  2.30946D-04
# True
#
# At iterate    5    f=  2.99133D+01    |proj g|=  1.83091D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      7      5     0     0   1.831D-06   2.991D+01
#   F =   29.913297862041254
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.03271D+01    |proj g|=  3.07157D-01
# True
# True
#
# At iterate    1    f=  3.03247D+01    |proj g|=  1.81904D-01
#
# At iterate    2    f=  3.03236D+01    |proj g|=  1.29983D-01
#
# At iterate    3    f=  3.03228D+01    |proj g|=  6.39631D-03
#
# At iterate    4    f=  3.03228D+01    |proj g|=  2.26763D-04
#
# At iterate    5    f=  3.03228D+01    |proj g|=  2.93690D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      7      5     0     0   2.937D-06   3.032D+01
#   F =   30.322758731376783
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.09814D+01    |proj g|=  2.44167D-01
#
# At iterate    1    f=  3.09801D+01    |proj g|=  1.23521D-01
#
# At iterate    2    f=  3.09796D+01    |proj g|=  9.25949D-02
#
# At iterate    3    f=  3.09792D+01    |proj g|=  2.97018D-03
#
# At iterate    4    f=  3.09792D+01    |proj g|=  7.03620D-05
#
# At iterate    5    f=  3.09792D+01    |proj g|=  4.57537D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      7      5     0     0   4.575D-07   3.098D+01
#   F =   30.979169909672969
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.16033D+01    |proj g|=  5.48495D-02
#
# At iterate    1    f=  3.16031D+01    |proj g|=  2.09553D-02
#
# At iterate    2    f=  3.16031D+01    |proj g|=  1.49042D-03
#
# At iterate    3    f=  3.16031D+01    |proj g|=  1.48496D-05
# True
#
# At iterate    4    f=  3.16031D+01    |proj g|=  6.11403D-09
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      7      4     0     0   6.114D-09   3.160D+01
#   F =   31.603067202571872
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.22922D+01    |proj g|=  3.65669D-01
# True
#
# At iterate    1    f=  3.22851D+01    |proj g|=  3.25849D-01
#
# At iterate    2    f=  3.22822D+01    |proj g|=  1.77078D-01
#
# At iterate    3    f=  3.22813D+01    |proj g|=  1.55142D-02
#
# At iterate    4    f=  3.22813D+01    |proj g|=  7.54012D-04
#
# At iterate    5    f=  3.22813D+01    |proj g|=  1.41855D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   1.419D-05   3.228D+01
#   F =   32.281264370927744
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.28978D+01    |proj g|=  2.04086D-01
#
# At iterate    1    f=  3.28965D+01    |proj g|=  1.69710D-01
#
# At iterate    2    f=  3.28961D+01    |proj g|=  6.65222D-02
#
# At iterate    3    f=  3.28960D+01    |proj g|=  1.52402D-03
# True
#
# At iterate    4    f=  3.28960D+01    |proj g|=  6.52138D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      6      4     0     0   6.521D-06   3.290D+01
#   F =   32.896023666742678
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.35045D+01    |proj g|=  3.31429D-01
#
# At iterate    1    f=  3.35029D+01    |proj g|=  1.73200D-01
#
# At iterate    2    f=  3.35024D+01    |proj g|=  1.31612D-01
#
# At iterate    3    f=  3.35018D+01    |proj g|=  6.83237D-03
#
# At iterate    4    f=  3.35018D+01    |proj g|=  2.05864D-04
# True
#
# At iterate    5    f=  3.35018D+01    |proj g|=  1.94955D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   1.950D-07   3.350D+01
#   F =   33.501843976970108
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# True
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.41203D+01    |proj g|=  4.22740D-01
#
# At iterate    1    f=  3.41164D+01    |proj g|=  3.18759D-01
#
# At iterate    2    f=  3.41144D+01    |proj g|=  5.27094D-02
#
# At iterate    3    f=  3.41144D+01    |proj g|=  2.86435D-03
#
# At iterate    4    f=  3.41144D+01    |proj g|=  4.11353D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      7      4     0     0   4.114D-05   3.411D+01
#   F =   34.114392794776208
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.46153D+01    |proj g|=  8.58917D-01
#
# At iterate    1    f=  3.46075D+01    |proj g|=  2.07504D-01
#
# At iterate    2    f=  3.46069D+01    |proj g|=  1.14694D-01
#
# At iterate    3    f=  3.46064D+01    |proj g|=  8.27904D-02
#
# At iterate    4    f=  3.46063D+01    |proj g|=  1.42666D-02
#
# At iterate    5    f=  3.46063D+01    |proj g|=  6.93550D-04
# True
#
# At iterate    6    f=  3.46063D+01    |proj g|=  2.55167D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6      9      7     0     0   2.552D-05   3.461D+01
#   F =   34.606302620085806
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.47722D+01    |proj g|=  1.12193D-01
#
# At iterate    1    f=  3.47716D+01    |proj g|=  5.69595D-02
#
# At iterate    2    f=  3.47716D+01    |proj g|=  7.72513D-03
#
# At iterate    3    f=  3.47716D+01    |proj g|=  1.08774D-04
# True
#
# At iterate    4    f=  3.47716D+01    |proj g|=  1.34793D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      7      4     0     0   1.348D-07   3.477D+01
#   F =   34.771560901812578
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# True
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.50712D+01    |proj g|=  3.10935D-01
#
# At iterate    1    f=  3.50697D+01    |proj g|=  5.16669D-02
#
# At iterate    2    f=  3.50697D+01    |proj g|=  3.72444D-02
#
# At iterate    3    f=  3.50696D+01    |proj g|=  1.53998D-02
#
# At iterate    4    f=  3.50696D+01    |proj g|=  1.04167D-03
#
# At iterate    5    f=  3.50696D+01    |proj g|=  4.59186D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   4.592D-05   3.507D+01
#   F =   35.069616815755474
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.59689D+01    |proj g|=  3.01723D-01
#
# At iterate    1    f=  3.59683D+01    |proj g|=  7.73104D-02
#
# At iterate    2    f=  3.59682D+01    |proj g|=  6.64265D-02
#
# At iterate    3    f=  3.59681D+01    |proj g|=  2.41235D-03
# True
#
# At iterate    4    f=  3.59681D+01    |proj g|=  3.72859D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      7      4     0     0   3.729D-05   3.597D+01
#   F =   35.968131593866417
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.63597D+01    |proj g|=  4.77202D-01
# True
#
# At iterate    1    f=  3.63557D+01    |proj g|=  2.76794D-01
#
# At iterate    2    f=  3.63546D+01    |proj g|=  1.86881D-01
#
# At iterate    3    f=  3.63530D+01    |proj g|=  9.55618D-03
#
# At iterate    4    f=  3.63530D+01    |proj g|=  3.50593D-04
#
# At iterate    5    f=  3.63530D+01    |proj g|=  2.41952D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   2.420D-06   3.635D+01
#   F =   36.352999274505180
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.68747D+01    |proj g|=  2.96110D-01
#
# At iterate    1    f=  3.68737D+01    |proj g|=  3.55025D-02
#
# At iterate    2    f=  3.68737D+01    |proj g|=  1.99983D-02
#
# At iterate    3    f=  3.68737D+01    |proj g|=  1.34578D-02
#
# At iterate    4    f=  3.68737D+01    |proj g|=  2.04130D-03
# True
#
# At iterate    5    f=  3.68737D+01    |proj g|=  1.36571D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   1.366D-04   3.687D+01
#   F =   36.873679042532160
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.73734D+01    |proj g|=  2.91472D-01
#
# At iterate    1    f=  3.73723D+01    |proj g|=  2.05950D-01
#
# At iterate    2    f=  3.73718D+01    |proj g|=  1.16238D-01
#
# At iterate    3    f=  3.73716D+01    |proj g|=  3.16982D-03
#
# At iterate    4    f=  3.73716D+01    |proj g|=  5.11985D-05
# True
#
# At iterate    5    f=  3.73716D+01    |proj g|=  3.29338D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   3.293D-07   3.737D+01
#   F =   37.371626946315509
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# True
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.78672D+01    |proj g|=  1.13363D-01
#
# At iterate    1    f=  3.78670D+01    |proj g|=  8.82819D-02
#
# At iterate    2    f=  3.78670D+01    |proj g|=  1.70937D-02
#
# At iterate    3    f=  3.78669D+01    |proj g|=  1.30271D-04
#
# At iterate    4    f=  3.78669D+01    |proj g|=  2.34471D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      6      4     0     0   2.345D-07   3.787D+01
#   F =   37.866948317787745
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.83360D+01    |proj g|=  1.10498D-01
#
# At iterate    1    f=  3.83358D+01    |proj g|=  8.02232D-02
#
# At iterate    2    f=  3.83358D+01    |proj g|=  5.47012D-02
#
# At iterate    3    f=  3.83358D+01    |proj g|=  3.29237D-04
# True
#
# At iterate    4    f=  3.83358D+01    |proj g|=  8.75703D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      6      4     0     0   8.757D-07   3.834D+01
#   F =   38.335757764530364
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.92051D+01    |proj g|=  2.36535D-01
# True
#
# At iterate    1    f=  3.92046D+01    |proj g|=  8.03165D-02
#
# At iterate    2    f=  3.92046D+01    |proj g|=  3.23150D-02
#
# At iterate    3    f=  3.92045D+01    |proj g|=  2.54228D-02
#
# At iterate    4    f=  3.92045D+01    |proj g|=  4.81887D-03
#
# At iterate    5    f=  3.92045D+01    |proj g|=  1.65539D-04
#
# At iterate    6    f=  3.92045D+01    |proj g|=  7.37942D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6      8      6     0     0   7.379D-06   3.920D+01
#   F =   39.204533088650521
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.96722D+01    |proj g|=  5.60370D-01
#
# At iterate    1    f=  3.96670D+01    |proj g|=  1.19765D-01
#
# At iterate    2    f=  3.96668D+01    |proj g|=  1.03369D-01
#
# At iterate    3    f=  3.96666D+01    |proj g|=  7.67305D-03
#
# At iterate    4    f=  3.96666D+01    |proj g|=  1.93837D-04
# True
#
# At iterate    5    f=  3.96666D+01    |proj g|=  1.56736D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   1.567D-06   3.967D+01
#   F =   39.666580434644843
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.94131D+01    |proj g|=  1.46142D-01
#
# At iterate    1    f=  3.94130D+01    |proj g|=  6.96665D-02
#
# At iterate    2    f=  3.94129D+01    |proj g|=  4.99944D-02
#
# At iterate    3    f=  3.94129D+01    |proj g|=  3.78898D-04
# True
#
# At iterate    4    f=  3.94129D+01    |proj g|=  2.07127D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      6      4     0     0   2.071D-06   3.941D+01
#   F =   39.412884484536960
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.99901D+01    |proj g|=  2.72065D-01
#
# At iterate    1    f=  3.99894D+01    |proj g|=  3.65983D-02
#
# At iterate    2    f=  3.99894D+01    |proj g|=  2.24764D-02
#
# At iterate    3    f=  3.99894D+01    |proj g|=  1.29352D-02
#
# At iterate    4    f=  3.99894D+01    |proj g|=  1.57298D-03
# True
#
# At iterate    5    f=  3.99894D+01    |proj g|=  9.72710D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   9.727D-05   3.999D+01
#   F =   39.989397607406062
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.99476D+01    |proj g|=  1.92791D-01
#
# At iterate    1    f=  3.99469D+01    |proj g|=  3.81721D-02
#
# At iterate    2    f=  3.99468D+01    |proj g|=  3.02742D-04
# True
#
# At iterate    3    f=  3.99468D+01    |proj g|=  5.10280D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      6      3     0     0   5.103D-06   3.995D+01
#   F =   39.946847350418757
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# True
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.03447D+01    |proj g|=  1.34846D-01
#
# At iterate    1    f=  4.03446D+01    |proj g|=  1.29555D-02
#
# At iterate    2    f=  4.03446D+01    |proj g|=  5.93236D-03
#
# At iterate    3    f=  4.03446D+01    |proj g|=  4.71646D-03
#
# At iterate    4    f=  4.03446D+01    |proj g|=  9.24665D-04
#
# At iterate    5    f=  4.03446D+01    |proj g|=  4.58197D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      7      5     0     0   4.582D-05   4.034D+01
#   F =   40.344560229656580
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.17353D+01    |proj g|=  2.42119D+00
#
# At iterate    1    f=  4.17263D+01    |proj g|=  1.15301D+00
#
# At iterate    2    f=  4.17099D+01    |proj g|=  2.67635D-01
#
# At iterate    3    f=  4.17094D+01    |proj g|=  1.28929D-01
#
# At iterate    4    f=  4.17092D+01    |proj g|=  7.36300D-02
#
# At iterate    5    f=  4.17091D+01    |proj g|=  7.34599D-03
#
# At iterate    6    f=  4.17091D+01    |proj g|=  1.83967D-04
# True
#
# At iterate    7    f=  4.17091D+01    |proj g|=  9.10489D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      7     10      8     0     0   9.105D-06   4.171D+01
#   F =   41.709103279190913
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.22026D+01    |proj g|=  8.25557D-02
#
# At iterate    1    f=  4.22026D+01    |proj g|=  5.74473D-02
#
# At iterate    2    f=  4.22025D+01    |proj g|=  2.52242D-02
#
# At iterate    3    f=  4.22025D+01    |proj g|=  1.34366D-04
# True
#
# At iterate    4    f=  4.22025D+01    |proj g|=  4.48611D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      6      4     0     0   4.486D-07   4.220D+01
#   F =   42.202534728597264
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.28018D+01    |proj g|=  2.73976D-01
#
# At iterate    1    f=  4.28013D+01    |proj g|=  1.74780D-01
#
# At iterate    2    f=  4.28012D+01    |proj g|=  7.31633D-02
# True
#
# At iterate    3    f=  4.28011D+01    |proj g|=  3.30644D-02
#
# At iterate    4    f=  4.28011D+01    |proj g|=  3.95842D-03
#
# At iterate    5    f=  4.28011D+01    |proj g|=  4.05744D-05
#
# At iterate    6    f=  4.28011D+01    |proj g|=  1.56693D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6      8      6     0     0   1.567D-06   4.280D+01
#   F =   42.801057391932915
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.39526D+01    |proj g|=  9.89146D-01
#
# At iterate    1    f=  4.39477D+01    |proj g|=  2.16613D-01
#
# At iterate    2    f=  4.39475D+01    |proj g|=  4.87056D-02
#
# At iterate    3    f=  4.39474D+01    |proj g|=  4.28315D-02
#
# At iterate    4    f=  4.39474D+01    |proj g|=  4.54907D-03
#
# At iterate    5    f=  4.39474D+01    |proj g|=  5.25711D-05
# True
#
# At iterate    6    f=  4.39474D+01    |proj g|=  1.30422D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# ...
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.38910D+01    |proj g|=  3.04369D-01
#
# At iterate    1    f=  5.38905D+01    |proj g|=  5.16389D-02
#
# At iterate    2    f=  5.38905D+01    |proj g|=  3.65720D-02
#
# At iterate    3    f=  5.38905D+01    |proj g|=  4.93236D-03
# True
#
# At iterate    4    f=  5.38905D+01    |proj g|=  2.48986D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      7      5     0     0   2.490D-05   5.389D+01
#   F =   53.890508748960002
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.33819D+01    |proj g|=  5.28607D-01
#
# At iterate    1    f=  5.33799D+01    |proj g|=  9.15268D-02
#
# At iterate    2    f=  5.33799D+01    |proj g|=  6.97045D-02
#
# At iterate    3    f=  5.33798D+01    |proj g|=  2.28463D-03
# True
#
# At iterate    4    f=  5.33798D+01    |proj g|=  1.98256D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      7      5     0     0   1.983D-05   5.338D+01
#   F =   53.379820937983453
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.33438D+01    |proj g|=  7.05622D-02
#
# At iterate    1    f=  5.33438D+01    |proj g|=  1.50963D-02
#
# At iterate    2    f=  5.33438D+01    |proj g|=  1.08136D-02
#
# At iterate    3    f=  5.33438D+01    |proj g|=  1.07173D-05
# True
#
# At iterate    4    f=  5.33438D+01    |proj g|=  5.92490D-09
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      6      4     0     0   5.925D-09   5.334D+01
#   F =   53.343790027696642
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.26865D+01    |proj g|=  2.98508D-01
#
# At iterate    1    f=  5.26862D+01    |proj g|=  1.59899D-02
#
# At iterate    2    f=  5.26862D+01    |proj g|=  4.19693D-04
# True
#
# At iterate    3    f=  5.26862D+01    |proj g|=  2.87830D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      6      4     0     0   2.878D-04   5.269D+01
#   F =   52.686231065301243
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.36903D+01    |proj g|=  1.95275D+00
#
# At iterate    1    f=  5.36809D+01    |proj g|=  7.00461D-01
#
# At iterate    2    f=  5.36792D+01    |proj g|=  4.51238D-01
#
# At iterate    3    f=  5.36778D+01    |proj g|=  1.19455D-02
#
# At iterate    4    f=  5.36778D+01    |proj g|=  2.35031D-04
# True
#
# At iterate    5    f=  5.36778D+01    |proj g|=  4.40427D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      5     0     0   4.404D-06   5.368D+01
#   F =   53.677835517802791
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.34420D+01    |proj g|=  3.27111D-01
#
# At iterate    1    f=  5.34415D+01    |proj g|=  2.09221D-01
#
# At iterate    2    f=  5.34413D+01    |proj g|=  4.19577D-02
# At iterate    3    f=  5.34413D+01    |proj g|=  3.02311D-04
# True
#
# At iterate    4    f=  5.34413D+01    |proj g|=  8.82816D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      7      4     0     0   8.828D-07   5.344D+01
#   F =   53.441339263596532
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.34628D+01    |proj g|=  7.23590D-01
#
# At iterate    1    f=  5.34604D+01    |proj g|=  1.63341D-01
#
# At iterate    2    f=  5.34603D+01    |proj g|=  6.11583D-02
#
# At iterate    3    f=  5.34603D+01    |proj g|=  1.33906D-02
#
# At iterate    4    f=  5.34603D+01    |proj g|=  8.87771D-04
# True
#
# At iterate    5    f=  5.34603D+01    |proj g|=  1.32410D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   1.324D-06   5.346D+01
#   F =   53.460309852491605
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.38373D+01    |proj g|=  2.96297D-02
#
# At iterate    1    f=  5.38373D+01    |proj g|=  1.20865D-02
#
# At iterate    2    f=  5.38373D+01    |proj g|=  7.72998D-03
# True
#
# At iterate    3    f=  5.38373D+01    |proj g|=  8.66088D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      3     0     0   8.661D-06   5.384D+01
#   F =   53.837253702922709
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.35680D+01    |proj g|=  5.60574D-01
#
# At iterate    1    f=  5.35662D+01    |proj g|=  3.44052D-02
#
# At iterate    2    f=  5.35662D+01    |proj g|=  3.86782D-03
# True
#
# At iterate    3    f=  5.35662D+01    |proj g|=  2.72348D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      6      4     0     0   2.723D-03   5.357D+01
#   F =   53.566180731969467
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.37102D+01    |proj g|=  9.44271D-02
#
# At iterate    1    f=  5.37102D+01    |proj g|=  6.14464D-02
#
# At iterate    2    f=  5.37101D+01    |proj g|=  5.47756D-03
# True
#
# At iterate    3    f=  5.37101D+01    |proj g|=  1.24638D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      3     0     0   1.246D-05   5.371D+01
#   F =   53.710138879406344
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.37495D+01    |proj g|=  3.04965D-01
#
# At iterate    1    f=  5.37489D+01    |proj g|=  4.59851D-02
#
# At iterate    2    f=  5.37489D+01    |proj g|=  2.49628D-02
#
# At iterate    3    f=  5.37489D+01    |proj g|=  7.24419D-03
#
# At iterate    4    f=  5.37489D+01    |proj g|=  2.82238D-04
# True
#
# At iterate    5    f=  5.37489D+01    |proj g|=  8.96423D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   8.964D-06   5.375D+01
#   F =   53.748911245778544
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.37937D+01    |proj g|=  7.90136D-01
#
# At iterate    1    f=  5.37910D+01    |proj g|=  2.15735D-01
#
# At iterate    2    f=  5.37909D+01    |proj g|=  8.03618D-02
#
# At iterate    3    f=  5.37909D+01    |proj g|=  1.24946D-02
#
# At iterate    4    f=  5.37909D+01    |proj g|=  6.38650D-04
# True
#
# At iterate    5    f=  5.37909D+01    |proj g|=  1.24247D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      8      6     0     0   1.242D-06   5.379D+01
#   F =   53.790858987912443
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.46595D+01    |proj g|=  3.02109D-01
#
# At iterate    1    f=  5.46585D+01    |proj g|=  1.38398D-01
#
# At iterate    2    f=  5.46584D+01    |proj g|=  1.15279D-01
#
# At iterate    3    f=  5.46583D+01    |proj g|=  3.48047D-03
# True
#
# At iterate    4    f=  5.46583D+01    |proj g|=  2.40523D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      7      5     0     0   2.405D-05   5.466D+01
#   F =   54.658288126535098
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.47005D+01    |proj g|=  2.37193D-01
#
# At iterate    1    f=  5.47003D+01    |proj g|=  8.74519D-02
#
# At iterate    2    f=  5.47003D+01    |proj g|=  3.57955D-02
#
# At iterate    3    f=  5.47002D+01    |proj g|=  1.88576D-02
#
# At iterate    4    f=  5.47002D+01    |proj g|=  1.82082D-03
# True
#
# At iterate    5    f=  5.47002D+01    |proj g|=  7.33203D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      7      5     0     0   7.332D-05   5.470D+01
#   F =   54.700235836137324
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.43961D+01    |proj g|=  1.62607D-01
#
# At iterate    1    f=  5.43960D+01    |proj g|=  9.29051D-02
#
# At iterate    2    f=  5.43959D+01    |proj g|=  4.66771D-02
#
# At iterate    3    f=  5.43959D+01    |proj g|=  1.73253D-04
# True
#
# At iterate    4    f=  5.43959D+01    |proj g|=  4.06266D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      6      4     0     0   4.063D-07   5.440D+01
#   F =   54.395927061827138
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL

# %%
time.strftime("%H:%M:%S", time.gmtime(elapsed_time))
g = ak.surrogate.predict(ak.learning_set, False)
n_ = ak.learning_set.shape[0] + len(ak.qoi)
pf = (sum(g < 0) + sum(np.array(ak.qoi) < 0)) / n_
print('Time: ', elapsed_time)
print('Function evaluation: ', ak.samples.shape[0])
print('Probability of failure: ', pf)
# Out:
# Time:  3.11271595954895
# Function evaluation:  100
# Probability of failure:  [0.61272727]

# %% [markdown]
# This figure shows the location of new samples generated using active learning function.

# %%
fig1, ax1 = plt.subplots()
kr_a = ax1.contour(x1v, x2v, y_act, levels=[0], colors='Black')

# Plot for scattered data
ID1 = ax1.scatter(ak.samples[nd:, 0], ak.samples[nd:, 1], color='Grey', label='New samples')
ID = ax1.scatter(x.samples[:nd, 0], x.samples[:nd, 1], color='Red', label='Initial samples')
plt.legend(handles=[ID1, ID])
plt.show()

# %% [markdown]
# ## Monte Carlo Simulation

# %% [markdown]
# Probability of failure and covariance is estimated using Monte Carlo Simulation. 10,000 samples are generated randomly using MCS class and model is evaluated at all samples.

# %%
start_time = time.time()

# Code
b = MonteCarloSampling(distributions=marginals, nsamples=10 ** 4, random_state=4)
r1model = RunModel(model_script='series.py', vec=False)
r1model.run(samples=b.samples)
gx = np.array(r1model.qoi_list)
pf_mcs = np.sum(np.array(gx) < 0) / b.nsamples
cov_pf_mcs = np.sqrt((1 - pf_mcs) / (pf_mcs * b.nsamples))
elapsed_time = time.time() - start_time
time.strftime("%H:%M:%S", time.gmtime(elapsed_time))
# Out:
# '00:00:00'

# %% [markdown]
# Results from Monte Carlo Simulation.

# %%
print('Time: ', elapsed_time)
print('Function evaluation: ', b.nsamples)
print('Probability of failure: ', pf_mcs)
# Out:
# Time:  0.4436228275299072
# Function evaluation:  10000
# Probability of failure:  0.5995
