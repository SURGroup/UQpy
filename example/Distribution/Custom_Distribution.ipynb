# %% [markdown]
# # Custom Distribution Example
# Author: Michael D. Shields
#
# Date: 8/20/2018, Last modified on 3/5/2019 by Dimitris Giovanis
#
# Illustrates the Distribution class of UQpy for a custom defined Weibull distribution

# %% [markdown]
# Import the necessary modules

# %%
from UQpy.Distributions import Distribution
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats

# %% [markdown]
# Instatiate a custom distribution object

# %%
dist = Distribution(dist_name='custom_dist')

# %% [markdown]
# Plot the pdf of the distribution.
# Notice that when calling the pdf, the parameters of the distribution must be specified.

# %%
x = np.linspace(0.01,4,1000)
plt.plot(x, dist.pdf(x, params=[1,0.5]))
plt.xlabel("x", Fontsize=20)
plt.ylabel("pdf",Fontsize=20)
plt.grid(True)
plt.title("Custom distribution")
plt.show()

# %% [markdown]
# Plot the log_pdf of the distribution.
# Notice that when calling the log_pdf, the parameters of the distribution must be specified.

# %%
plt.plot(x, dist.log_pdf(x, params=[1,0.5]))
plt.xlabel("x", Fontsize=20)
plt.ylabel("log_pdf",Fontsize=20)
plt.grid(True)
plt.title("Custom distribution")
plt.show()

# %% [markdown]
# Plot the cdf of the distribution.
# Notice that when calling the cdf, the parameters of the distribution must be specified.

# %%
x = np.linspace(0.01,4,1000)
plt.plot(x, dist.cdf(x, params=[1,0.5]))
plt.xlabel("x", Fontsize=20)
plt.ylabel("cdf",Fontsize=20)
plt.grid(True)
plt.title("Custom distribution")
plt.show()

# %% [markdown]
# Plot the inverse cdf of the distribution.
# Notice that when calling the inverse cdf, the parameters of the distribution must be specified.

# %%
plt.plot(x, dist.icdf(x, params=[1,0.5]))
plt.xlabel("x", Fontsize=20)
plt.ylabel("inverse cdf",Fontsize=20)
plt.grid(True)
plt.title("Custom distribution")
plt.show()
# Out:
# /Users/dimitrisgiovanis/PycharmProjects/UQpy/example/Distribution/custom_dist.py:11: RuntimeWarning: invalid value encountered in log
#   return params[0]*(-np.log(1-x))**(1/params[1])

# %% [markdown]
# Check the remaining attributes of the custom distribution. Notice that these are not defined in custom_dist.py. By default, the code returns the statement 'Attribute not defined.'

# %%
dist.rvs(params=[1,0.5], nsamples=1000)
# Out:
# ---------------------------------------------------------------------------
# UserWarning                               Traceback (most recent call last)
# <ipython-input-7-ef5ca626b556> in <module>()
# ----> 1 dist.rvs(params=[1,0.5], nsamples=1000)
#
# /Users/dimitrisgiovanis/PycharmProjects/UQpy/src/UQpy/Distributions.py in rvs(self, params, nsamples)
#     146
#     147         if isinstance(self.dist_name, str):
# --> 148             return SubDistribution(dist_name=self.dist_name).rvs(params, nsamples)
#     149         elif isinstance(self.dist_name, list):
#     150             if len(params) != len(self.dist_name):
#
# /Users/dimitrisgiovanis/PycharmProjects/UQpy/src/UQpy/Distributions.py in rvs(self, params, nsamples)
#     388             tmp = getattr(custom_dist, 'rvs', None)
#     389             if tmp is None:
# --> 390                 raise UserWarning('Method "rvs" not defined by the user in '+self.dist_name+'.')
#     391             else:
#     392                 return tmp(params, nsamples)
#
# UserWarning: Method "rvs" not defined by the user in custom_dist.

# %%
dist.moments(x)

# %%
dist.fit(x)
