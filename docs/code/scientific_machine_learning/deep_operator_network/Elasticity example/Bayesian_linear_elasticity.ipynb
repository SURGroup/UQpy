# %%
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from scipy.io import savemat
from matplotlib import pyplot as plt

from UQpy.scientific_machine_learning.neural_networks import DeepOperatorNetwork
from UQpy.scientific_machine_learning.trainers import BBBTrainer
from UQpy.scientific_machine_learning.layers.BayesianLayer import BayesianLayer
from UQpy.scientific_machine_learning.layers.BayesianConvLayer import BayesianConvLayer
from dataset import load_data, rescale

import logging

logger = logging.getLogger("UQpy")
logger.setLevel(logging.INFO)

# %%
priors = {
    "prior_mu": 0,
    "prior_sigma": 0.01,
    "posterior_mu_initial": (0, 0.1),
    "posterior_rho_initial": (-5, 0.1),
}

# %%
class BranchNet(nn.Module):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.fnn = nn.Sequential(BayesianLayer(101, 100, priors=priors), nn.Tanh())
        self.conv_layers = nn.Sequential(
            BayesianConvLayer(1, 16, (5, 5), padding="same", priors=priors),
            nn.AvgPool2d(2, 1, padding=0),
            BayesianConvLayer(16, 16, (5, 5), padding="same", priors=priors),
            nn.AvgPool2d(2, 1, padding=0),
            BayesianConvLayer(16, 16, (5, 5), padding="same", priors=priors),
            nn.AvgPool2d(2, 1, padding=0),
            BayesianConvLayer(16, 64, (5, 5), padding="same", priors=priors),
            nn.AvgPool2d(2, 1, padding=0),
        )
        self.dnn = nn.Sequential(
            nn.Flatten(),
            BayesianLayer(64 * 6 * 6, 512, priors=priors),
            nn.Tanh(),
            BayesianLayer(512, 512, priors=priors),
            nn.Tanh(),
            BayesianLayer(512, 200, priors=priors),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.fnn(x)
        x = x.view(-1, 1, 10, 10)
        x = self.conv_layers(x)
        x = self.dnn(x)
        return x

# %%
class TrunkNet(nn.Module):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.fnn = nn.Sequential(
            BayesianLayer(2, 128, priors=priors),
            nn.Tanh(),
            BayesianLayer(128, 128, priors=priors),
            nn.Tanh(),
            BayesianLayer(128, 128, priors=priors),
            nn.Tanh(),
            BayesianLayer(128, 200, priors=priors),
            nn.Tanh(),
        )
        self.Xmin = np.array([0.0, 0.0]).reshape((-1, 2))
        self.Xmax = np.array([1.0, 1.0]).reshape((-1, 2))

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = 2.0 * (x - self.Xmin) / (self.Xmax - self.Xmin) - 1.0
        x = x.float()
        x = self.fnn(x)
        return x

# %%
branch_network = BranchNet()
trunk_network = TrunkNet()
model = DeepOperatorNetwork(branch_network, trunk_network, 2)

# %%
# Load datasets and create data loaders
class ElasticityDataSet(Dataset):
    """Load the Elasticity dataset"""

    def __init__(self, x, f_x, u_x, u_y):
        self.x = x
        self.f_x = f_x
        self.u_x = u_x
        self.u_y = u_y

    def __len__(self):
        return int(self.f_x.shape[0])

    def __getitem__(self, i):
        return self.x, self.f_x[i, :], (self.u_x[i, :, 0], self.u_y[i, :, 0])

(F_train,Ux_train, Uy_train, F_test, Ux_test, Uy_test,
    X, ux_train_mean, ux_train_std, uy_train_mean, uy_train_std,) = load_data()
train_data = DataLoader(
    ElasticityDataSet(
        np.float32(X), np.float32(F_train), np.float32(Ux_train), np.float32(Uy_train)
    ),
    batch_size=100,
    shuffle=True,
)
test_data = DataLoader(
    ElasticityDataSet(
        np.float32(X), np.float32(F_test), np.float32(Ux_test), np.float32(Uy_test)
    ),
    batch_size=100,
    shuffle=True,
)

# %%
class LossFunction(nn.Module):
    def __init__(self, reduction: str = "mean", *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.reduction = reduction

    def forward(self, prediction, label):
        return F.mse_loss(
            prediction[0], label[0], reduction=self.reduction
        ) + F.mse_loss(prediction[1], label[1], reduction=self.reduction)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
trainer = BBBTrainer(model, optimizer, LossFunction())

# %%
trainer.run(
    train_data=train_data,
    test_data=test_data,
    epochs=1000,
    tolerance=1e-4,
    beta=1e-8,
    num_samples=1,
)
# Out:
# [INFO] - 2024-05-15 18:52:22,455 - UQpy: Scientific Machine Learning: Beginning training and testing DeepOperatorNetwork
# [INFO] - 2024-05-15 18:52:26,459 - UQpy: Scientific Machine Learning: Epoch 1 / 1,000 Train Loss 71.02275715376202 Train NLL 70.19425618021111 Train KL 82850136.0 Test NLL 12.179424285888672
# [INFO] - 2024-05-15 18:52:30,399 - UQpy: Scientific Machine Learning: Epoch 2 / 1,000 Train Loss 6.098675426683928 Train NLL 5.270535343571713 Train KL 82814016.0 Test NLL 2.8961684703826904
# [INFO] - 2024-05-15 18:52:34,333 - UQpy: Scientific Machine Learning: Epoch 3 / 1,000 Train Loss 2.946959972381592 Train NLL 2.1197758787556698 Train KL 82718408.0 Test NLL 1.8136175870895386
# [INFO] - 2024-05-15 18:52:38,272 - UQpy: Scientific Machine Learning: Epoch 4 / 1,000 Train Loss 2.6266378728966964 Train NLL 1.8005676959690295 Train KL 82607032.0 Test NLL 1.3812694549560547
# [INFO] - 2024-05-15 18:52:42,261 - UQpy: Scientific Machine Learning: Epoch 5 / 1,000 Train Loss 2.7742326698805155 Train NLL 1.9492169430381374 Train KL 82501568.0 Test NLL 1.545756220817566
# [INFO] - 2024-05-15 18:52:46,261 - UQpy: Scientific Machine Learning: Epoch 6 / 1,000 Train Loss 2.5500254191850362 Train NLL 1.7259857936909324 Train KL 82403960.0 Test NLL 1.3105151653289795
# [INFO] - 2024-05-15 18:52:50,278 - UQpy: Scientific Machine Learning: Epoch 7 / 1,000 Train Loss 2.236629322955483 Train NLL 1.4134509500704313 Train KL 82317832.0 Test NLL 1.3390069007873535
# [INFO] - 2024-05-15 18:52:54,322 - UQpy: Scientific Machine Learning: Epoch 8 / 1,000 Train Loss 2.051021695137024 Train NLL 1.2286045017995333 Train KL 82241728.0 Test NLL 1.5100986957550049
# [INFO] - 2024-05-15 18:52:58,369 - UQpy: Scientific Machine Learning: Epoch 9 / 1,000 Train Loss 2.2531016061180518 Train NLL 1.4313586511110004 Train KL 82174296.0 Test NLL 1.2428539991378784
# [INFO] - 2024-05-15 18:53:02,411 - UQpy: Scientific Machine Learning: Epoch 10 / 1,000 Train Loss 2.034172723167821 Train NLL 1.2130205317547447 Train KL 82115224.0 Test NLL 1.4066016674041748
# [INFO] - 2024-05-15 18:53:06,471 - UQpy: Scientific Machine Learning: Epoch 11 / 1,000 Train Loss 2.0335225870734766 Train NLL 1.212946841591283 Train KL 82057576.0 Test NLL 1.5036351680755615
# [INFO] - 2024-05-15 18:53:10,539 - UQpy: Scientific Machine Learning: Epoch 12 / 1,000 Train Loss 2.074175652704741 Train NLL 1.2541324872719615 Train KL 82004320.0 Test NLL 1.0293910503387451
# [INFO] - 2024-05-15 18:53:14,571 - UQpy: Scientific Machine Learning: Epoch 13 / 1,000 Train Loss 2.00736141204834 Train NLL 1.1877922384362471 Train KL 81956920.0 Test NLL 2.0132393836975098
# [INFO] - 2024-05-15 18:53:18,556 - UQpy: Scientific Machine Learning: Epoch 14 / 1,000 Train Loss 1.9397487765864323 Train NLL 1.1206754885221784 Train KL 81907328.0 Test NLL 1.4248067140579224
# [INFO] - 2024-05-15 18:53:22,459 - UQpy: Scientific Machine Learning: Epoch 15 / 1,000 Train Loss 2.097888181084081 Train NLL 1.2793030142784119 Train KL 81858520.0 Test NLL 1.0792524814605713
# [INFO] - 2024-05-15 18:53:26,348 - UQpy: Scientific Machine Learning: Epoch 16 / 1,000 Train Loss 2.03871488571167 Train NLL 1.2206125635849803 Train KL 81810240.0 Test NLL 1.7323582172393799
# [INFO] - 2024-05-15 18:53:30,255 - UQpy: Scientific Machine Learning: Epoch 17 / 1,000 Train Loss 1.8976100369503623 Train NLL 1.0799971254248368 Train KL 81761288.0 Test NLL 1.0217314958572388
# [INFO] - 2024-05-15 18:53:34,244 - UQpy: Scientific Machine Learning: Epoch 18 / 1,000 Train Loss 1.9534938147193508 Train NLL 1.1363695797167326 Train KL 81712416.0 Test NLL 1.1048438549041748
# [INFO] - 2024-05-15 18:53:38,260 - UQpy: Scientific Machine Learning: Epoch 19 / 1,000 Train Loss 2.1613312834187557 Train NLL 1.34469431325009 Train KL 81663688.0 Test NLL 1.3675397634506226
# [INFO] - 2024-05-15 18:53:42,192 - UQpy: Scientific Machine Learning: Epoch 20 / 1,000 Train Loss 1.8300248133508783 Train NLL 1.0138743457041288 Train KL 81615040.0 Test NLL 1.6494345664978027
# [INFO] - 2024-05-15 18:53:46,088 - UQpy: Scientific Machine Learning: Epoch 21 / 1,000 Train Loss 1.8279621538363005 Train NLL 1.0123106178484464 Train KL 81565160.0 Test NLL 1.2782245874404907
# [INFO] - 2024-05-15 18:53:50,020 - UQpy: Scientific Machine Learning: Epoch 22 / 1,000 Train Loss 1.830461156995673 Train NLL 1.0153116176002903 Train KL 81514960.0 Test NLL 1.0958476066589355
# [INFO] - 2024-05-15 18:53:53,931 - UQpy: Scientific Machine Learning: Epoch 23 / 1,000 Train Loss 2.146699955588893 Train NLL 1.332046113516155 Train KL 81465392.0 Test NLL 1.5801039934158325
# [INFO] - 2024-05-15 18:53:57,879 - UQpy: Scientific Machine Learning: Epoch 24 / 1,000 Train Loss 2.239773756579349 Train NLL 1.4256086286745573 Train KL 81416504.0 Test NLL 2.205793857574463
# [INFO] - 2024-05-15 18:54:01,804 - UQpy: Scientific Machine Learning: Epoch 25 / 1,000 Train Loss 1.9397215466750295 Train NLL 1.1260345546822799 Train KL 81368704.0 Test NLL 1.5577380657196045
# [INFO] - 2024-05-15 18:54:05,714 - UQpy: Scientific Machine Learning: Epoch 26 / 1,000 Train Loss 2.2123217582702637 Train NLL 1.3991292840556095 Train KL 81319248.0 Test NLL 1.065692663192749
# [INFO] - 2024-05-15 18:54:09,596 - UQpy: Scientific Machine Learning: Epoch 27 / 1,000 Train Loss 1.731434571115594 Train NLL 0.9187325772486234 Train KL 81270208.0 Test NLL 1.0243771076202393
# [INFO] - 2024-05-15 18:54:13,547 - UQpy: Scientific Machine Learning: Epoch 28 / 1,000 Train Loss 1.7561552587308382 Train NLL 0.9439494735316226 Train KL 81220584.0 Test NLL 0.9221442341804504
# [INFO] - 2024-05-15 18:54:17,494 - UQpy: Scientific Machine Learning: Epoch 29 / 1,000 Train Loss 1.676022962519997 Train NLL 0.8643176869342202 Train KL 81170536.0 Test NLL 0.8895531296730042
# [INFO] - 2024-05-15 18:54:21,418 - UQpy: Scientific Machine Learning: Epoch 30 / 1,000 Train Loss 1.7791237831115723 Train NLL 0.9679239360909713 Train KL 81119976.0 Test NLL 1.1946911811828613
# [INFO] - 2024-05-15 18:54:25,346 - UQpy: Scientific Machine Learning: Epoch 31 / 1,000 Train Loss 1.7274006605148315 Train NLL 0.9167043315736871 Train KL 81069632.0 Test NLL 0.8372998237609863
# [INFO] - 2024-05-15 18:54:29,248 - UQpy: Scientific Machine Learning: Epoch 32 / 1,000 Train Loss 1.6288921895780062 Train NLL 0.8186976439074466 Train KL 81019456.0 Test NLL 0.9443191289901733
# [INFO] - 2024-05-15 18:54:33,170 - UQpy: Scientific Machine Learning: Epoch 33 / 1,000 Train Loss 1.664555781765988 Train NLL 0.8548652090524372 Train KL 80969064.0 Test NLL 1.0711719989776611
# [INFO] - 2024-05-15 18:54:37,067 - UQpy: Scientific Machine Learning: Epoch 34 / 1,000 Train Loss 1.6581831480327405 Train NLL 0.8489979474168075 Train KL 80918520.0 Test NLL 1.1786770820617676
# [INFO] - 2024-05-15 18:54:40,953 - UQpy: Scientific Machine Learning: Epoch 35 / 1,000 Train Loss 1.7298614602339895 Train NLL 0.9211858416858473 Train KL 80867560.0 Test NLL 1.115837812423706
# [INFO] - 2024-05-15 18:54:44,971 - UQpy: Scientific Machine Learning: Epoch 36 / 1,000 Train Loss 1.6852434120680158 Train NLL 0.8770730809161538 Train KL 80817040.0 Test NLL 0.9434322118759155
# [INFO] - 2024-05-15 18:54:48,857 - UQpy: Scientific Machine Learning: Epoch 37 / 1,000 Train Loss 1.7027810059095685 Train NLL 0.8951174554071928 Train KL 80766360.0 Test NLL 0.9275758862495422
# [INFO] - 2024-05-15 18:54:52,752 - UQpy: Scientific Machine Learning: Epoch 38 / 1,000 Train Loss 1.681995479684127 Train NLL 0.8748428570596796 Train KL 80715256.0 Test NLL 0.8330810070037842
# [INFO] - 2024-05-15 18:54:56,668 - UQpy: Scientific Machine Learning: Epoch 39 / 1,000 Train Loss 1.7787185154463117 Train NLL 0.972072455443834 Train KL 80664600.0 Test NLL 1.5325788259506226
# [INFO] - 2024-05-15 18:55:00,750 - UQpy: Scientific Machine Learning: Epoch 40 / 1,000 Train Loss 1.678404086514523 Train NLL 0.8722666031435916 Train KL 80613736.0 Test NLL 0.8204190731048584
# [INFO] - 2024-05-15 18:55:04,801 - UQpy: Scientific Machine Learning: Epoch 41 / 1,000 Train Loss 1.793494513160304 Train NLL 0.9878607204085902 Train KL 80563384.0 Test NLL 0.9133069515228271
# [INFO] - 2024-05-15 18:55:08,863 - UQpy: Scientific Machine Learning: Epoch 42 / 1,000 Train Loss 1.8126740455627441 Train NLL 1.0075461770358838 Train KL 80512792.0 Test NLL 1.3878872394561768
# [INFO] - 2024-05-15 18:55:12,848 - UQpy: Scientific Machine Learning: Epoch 43 / 1,000 Train Loss 1.7319621788827997 Train NLL 0.9273130297660828 Train KL 80464920.0 Test NLL 0.8014347553253174
# [INFO] - 2024-05-15 18:55:16,787 - UQpy: Scientific Machine Learning: Epoch 44 / 1,000 Train Loss 1.7250361568049382 Train NLL 0.9208710915163943 Train KL 80416504.0 Test NLL 0.9248296022415161
# [INFO] - 2024-05-15 18:55:20,729 - UQpy: Scientific Machine Learning: Epoch 45 / 1,000 Train Loss 1.6371059794174998 Train NLL 0.8334054193998638 Train KL 80370056.0 Test NLL 0.7896109819412231
# [INFO] - 2024-05-15 18:55:24,718 - UQpy: Scientific Machine Learning: Epoch 46 / 1,000 Train Loss 1.602950089856198 Train NLL 0.7997325564685621 Train KL 80321760.0 Test NLL 0.9563276767730713
# [INFO] - 2024-05-15 18:55:28,660 - UQpy: Scientific Machine Learning: Epoch 47 / 1,000 Train Loss 1.6926736204247725 Train NLL 0.8899571487778112 Train KL 80271648.0 Test NLL 0.824708104133606
# [INFO] - 2024-05-15 18:55:32,671 - UQpy: Scientific Machine Learning: Epoch 48 / 1,000 Train Loss 1.555247382113808 Train NLL 0.7530341713052047 Train KL 80221328.0 Test NLL 0.7911618947982788
# [INFO] - 2024-05-15 18:55:36,649 - UQpy: Scientific Machine Learning: Epoch 49 / 1,000 Train Loss 1.5803588942477578 Train NLL 0.7786614753698048 Train KL 80169752.0 Test NLL 0.8980956077575684
# [INFO] - 2024-05-15 18:55:40,622 - UQpy: Scientific Machine Learning: Epoch 50 / 1,000 Train Loss 1.6056973244014539 Train NLL 0.8044583091610357 Train KL 80123904.0 Test NLL 0.868780791759491
# [INFO] - 2024-05-15 18:55:44,538 - UQpy: Scientific Machine Learning: Epoch 51 / 1,000 Train Loss 1.553617144885816 Train NLL 0.7528398727115831 Train KL 80077728.0 Test NLL 0.735061764717102
# [INFO] - 2024-05-15 18:55:48,497 - UQpy: Scientific Machine Learning: Epoch 52 / 1,000 Train Loss 1.553643785024944 Train NLL 0.7533751443812722 Train KL 80026856.0 Test NLL 1.074225902557373
# [INFO] - 2024-05-15 18:55:52,491 - UQpy: Scientific Machine Learning: Epoch 53 / 1,000 Train Loss 1.5244652158335636 Train NLL 0.7247185848261181 Train KL 79974672.0 Test NLL 0.825774073600769
# [INFO] - 2024-05-15 18:55:56,450 - UQpy: Scientific Machine Learning: Epoch 54 / 1,000 Train Loss 1.603100431592841 Train NLL 0.8038757851249293 Train KL 79922472.0 Test NLL 1.1294447183609009
# [INFO] - 2024-05-15 18:56:00,445 - UQpy: Scientific Machine Learning: Epoch 55 / 1,000 Train Loss 1.5941917017886513 Train NLL 0.7954887637966558 Train KL 79870288.0 Test NLL 0.866134524345398
# [INFO] - 2024-05-15 18:56:04,368 - UQpy: Scientific Machine Learning: Epoch 56 / 1,000 Train Loss 1.521653545530219 Train NLL 0.7234715662504497 Train KL 79818200.0 Test NLL 1.0448319911956787
# [INFO] - 2024-05-15 18:56:08,345 - UQpy: Scientific Machine Learning: Epoch 57 / 1,000 Train Loss 1.5839070960095054 Train NLL 0.7862539228640104 Train KL 79765312.0 Test NLL 0.9417243003845215
# [INFO] - 2024-05-15 18:56:12,344 - UQpy: Scientific Machine Learning: Epoch 58 / 1,000 Train Loss 1.6926403986780267 Train NLL 0.8955184974168476 Train KL 79712192.0 Test NLL 0.9661917686462402
# [INFO] - 2024-05-15 18:56:16,373 - UQpy: Scientific Machine Learning: Epoch 59 / 1,000 Train Loss 1.662908485061244 Train NLL 0.8662883356997841 Train KL 79662016.0 Test NLL 0.7951308488845825
# [INFO] - 2024-05-15 18:56:20,478 - UQpy: Scientific Machine Learning: Epoch 60 / 1,000 Train Loss 1.805019410032975 Train NLL 1.0088943682218854 Train KL 79612512.0 Test NLL 0.9734421968460083
# [INFO] - 2024-05-15 18:56:24,561 - UQpy: Scientific Machine Learning: Epoch 61 / 1,000 Train Loss 1.6936771367725574 Train NLL 0.8980658477858493 Train KL 79561120.0 Test NLL 0.7456817626953125
# [INFO] - 2024-05-15 18:56:28,480 - UQpy: Scientific Machine Learning: Epoch 62 / 1,000 Train Loss 1.7151854226463719 Train NLL 0.9201059341430664 Train KL 79507944.0 Test NLL 1.1872563362121582
# [INFO] - 2024-05-15 18:56:32,360 - UQpy: Scientific Machine Learning: Epoch 63 / 1,000 Train Loss 1.6383242795341892 Train NLL 0.8437692632800654 Train KL 79455504.0 Test NLL 0.9991621971130371
# [INFO] - 2024-05-15 18:56:36,279 - UQpy: Scientific Machine Learning: Epoch 64 / 1,000 Train Loss 1.5862825983449031 Train NLL 0.7922562674472207 Train KL 79402624.0 Test NLL 1.225520372390747
# [INFO] - 2024-05-15 18:56:40,160 - UQpy: Scientific Machine Learning: Epoch 65 / 1,000 Train Loss 1.5646134301235801 Train NLL 0.7711080783291867 Train KL 79350528.0 Test NLL 0.7737510800361633
# [INFO] - 2024-05-15 18:56:44,135 - UQpy: Scientific Machine Learning: Epoch 66 / 1,000 Train Loss 1.6736147529200505 Train NLL 0.8806398008999071 Train KL 79297512.0 Test NLL 0.8081647753715515
# [INFO] - 2024-05-15 18:56:48,094 - UQpy: Scientific Machine Learning: Epoch 67 / 1,000 Train Loss 1.559332671918367 Train NLL 0.7668984344131068 Train KL 79243424.0 Test NLL 0.9262221455574036
# [INFO] - 2024-05-15 18:56:52,062 - UQpy: Scientific Machine Learning: Epoch 68 / 1,000 Train Loss 1.5121075605091296 Train NLL 0.7202198646570507 Train KL 79188760.0 Test NLL 0.90280681848526
# [INFO] - 2024-05-15 18:56:55,989 - UQpy: Scientific Machine Learning: Epoch 69 / 1,000 Train Loss 1.6282693210401034 Train NLL 0.8369299581176356 Train KL 79133944.0 Test NLL 1.1897567510604858
# [INFO] - 2024-05-15 18:56:59,931 - UQpy: Scientific Machine Learning: Epoch 70 / 1,000 Train Loss 1.89166764209145 Train NLL 1.100873423250098 Train KL 79079432.0 Test NLL 1.2534645795822144
# [INFO] - 2024-05-15 18:57:03,780 - UQpy: Scientific Machine Learning: Epoch 71 / 1,000 Train Loss 1.6081435178455554 Train NLL 0.8178883979195043 Train KL 79025512.0 Test NLL 0.8754014372825623
# [INFO] - 2024-05-15 18:57:07,746 - UQpy: Scientific Machine Learning: Epoch 72 / 1,000 Train Loss 1.7587844698052657 Train NLL 0.9690671249439842 Train KL 78971736.0 Test NLL 1.7085514068603516
# [INFO] - 2024-05-15 18:57:11,659 - UQpy: Scientific Machine Learning: Epoch 73 / 1,000 Train Loss 2.109866970463803 Train NLL 1.3206562148897272 Train KL 78921080.0 Test NLL 1.0018690824508667
# [INFO] - 2024-05-15 18:57:15,531 - UQpy: Scientific Machine Learning: Epoch 74 / 1,000 Train Loss 1.7205777983916433 Train NLL 0.9318820473394895 Train KL 78869584.0 Test NLL 1.7035821676254272
# [INFO] - 2024-05-15 18:57:19,409 - UQpy: Scientific Machine Learning: Epoch 75 / 1,000 Train Loss 1.8815388616762663 Train NLL 1.0933718038232703 Train KL 78816704.0 Test NLL 0.9396480321884155
# [INFO] - 2024-05-15 18:57:23,433 - UQpy: Scientific Machine Learning: Epoch 76 / 1,000 Train Loss 1.7145665821276213 Train NLL 0.9269451122534903 Train KL 78762152.0 Test NLL 0.7808701395988464
# [INFO] - 2024-05-15 18:57:27,346 - UQpy: Scientific Machine Learning: Epoch 77 / 1,000 Train Loss 1.6580458314795243 Train NLL 0.8709772950724551 Train KL 78706840.0 Test NLL 0.9446061849594116
# [INFO] - 2024-05-15 18:57:31,462 - UQpy: Scientific Machine Learning: Epoch 78 / 1,000 Train Loss 1.7335441426226967 Train NLL 0.947034261728588 Train KL 78650992.0 Test NLL 1.1402360200881958
# [INFO] - 2024-05-15 18:57:35,486 - UQpy: Scientific Machine Learning: Epoch 79 / 1,000 Train Loss 1.5759780720660561 Train NLL 0.7900298363284061 Train KL 78594832.0 Test NLL 0.967469334602356
# [INFO] - 2024-05-15 18:57:39,390 - UQpy: Scientific Machine Learning: Epoch 80 / 1,000 Train Loss 1.6116081601695011 Train NLL 0.826230354999241 Train KL 78537784.0 Test NLL 0.8315737247467041
# [INFO] - 2024-05-15 18:57:43,329 - UQpy: Scientific Machine Learning: Epoch 81 / 1,000 Train Loss 1.6245766689902859 Train NLL 0.8397685524664427 Train KL 78480816.0 Test NLL 1.3373382091522217
# [INFO] - 2024-05-15 18:57:47,234 - UQpy: Scientific Machine Learning: Epoch 82 / 1,000 Train Loss 1.611857577374107 Train NLL 0.8276150697156003 Train KL 78424256.0 Test NLL 0.8075762391090393
# [INFO] - 2024-05-15 18:57:51,154 - UQpy: Scientific Machine Learning: Epoch 83 / 1,000 Train Loss 1.5563428025496633 Train NLL 0.7726549772839797 Train KL 78368784.0 Test NLL 1.1908063888549805
# [INFO] - 2024-05-15 18:57:55,187 - UQpy: Scientific Machine Learning: Epoch 84 / 1,000 Train Loss 1.9668455437610024 Train NLL 1.1837253413702313 Train KL 78312016.0 Test NLL 1.140830159187317
# [INFO] - 2024-05-15 18:57:59,318 - UQpy: Scientific Machine Learning: Epoch 85 / 1,000 Train Loss 1.5483274397097135 Train NLL 0.76577270344684 Train KL 78255472.0 Test NLL 1.0964388847351074
# [INFO] - 2024-05-15 18:58:03,418 - UQpy: Scientific Machine Learning: Epoch 86 / 1,000 Train Loss 1.5756835561049611 Train NLL 0.7937053692968268 Train KL 78197824.0 Test NLL 0.7722833156585693
# [INFO] - 2024-05-15 18:58:07,546 - UQpy: Scientific Machine Learning: Epoch 87 / 1,000 Train Loss 1.7571847376070524 Train NLL 0.9757850248562662 Train KL 78139968.0 Test NLL 0.8779035806655884
# [INFO] - 2024-05-15 18:58:11,771 - UQpy: Scientific Machine Learning: Epoch 88 / 1,000 Train Loss 1.6910824901179264 Train NLL 0.9102584468690973 Train KL 78082408.0 Test NLL 0.8261204361915588
# [INFO] - 2024-05-15 18:58:15,841 - UQpy: Scientific Machine Learning: Epoch 89 / 1,000 Train Loss 1.5612547272130062 Train NLL 0.7810174226760864 Train KL 78023736.0 Test NLL 0.8585336208343506
# [INFO] - 2024-05-15 18:58:20,042 - UQpy: Scientific Machine Learning: Epoch 90 / 1,000 Train Loss 1.6045758598729183 Train NLL 0.8249315023422241 Train KL 77964440.0 Test NLL 0.7721246480941772
# [INFO] - 2024-05-15 18:58:24,124 - UQpy: Scientific Machine Learning: Epoch 91 / 1,000 Train Loss 1.5336783998890926 Train NLL 0.7546284669323972 Train KL 77904992.0 Test NLL 0.8341034650802612
# [INFO] - 2024-05-15 18:58:28,205 - UQpy: Scientific Machine Learning: Epoch 92 / 1,000 Train Loss 1.6761913989719592 Train NLL 0.897738980619531 Train KL 77845240.0 Test NLL 0.880766749382019
# [INFO] - 2024-05-15 18:58:32,227 - UQpy: Scientific Machine Learning: Epoch 93 / 1,000 Train Loss 1.6722571222405684 Train NLL 0.8943866208979958 Train KL 77787048.0 Test NLL 0.7378981113433838
# [INFO] - 2024-05-15 18:58:36,268 - UQpy: Scientific Machine Learning: Epoch 94 / 1,000 Train Loss 1.817073947504947 Train NLL 1.0397750233349048 Train KL 77729896.0 Test NLL 1.260714054107666
# [INFO] - 2024-05-15 18:58:40,317 - UQpy: Scientific Machine Learning: Epoch 95 / 1,000 Train Loss 1.720478566069352 Train NLL 0.9437470091016669 Train KL 77673152.0 Test NLL 0.7913400530815125
# [INFO] - 2024-05-15 18:58:44,360 - UQpy: Scientific Machine Learning: Epoch 96 / 1,000 Train Loss 1.6796738724959523 Train NLL 0.9034900696654069 Train KL 77618376.0 Test NLL 0.8840705156326294
# [INFO] - 2024-05-15 18:58:48,255 - UQpy: Scientific Machine Learning: Epoch 97 / 1,000 Train Loss 1.8186922449814646 Train NLL 1.0430939542619806 Train KL 77559832.0 Test NLL 1.3494890928268433
# [INFO] - 2024-05-15 18:58:52,155 - UQpy: Scientific Machine Learning: Epoch 98 / 1,000 Train Loss 1.6718113234168606 Train NLL 0.8968126303271243 Train KL 77499880.0 Test NLL 0.8649910688400269
# [INFO] - 2024-05-15 18:58:56,048 - UQpy: Scientific Machine Learning: Epoch 99 / 1,000 Train Loss 1.731293985718175 Train NLL 0.9568858617230466 Train KL 77440808.0 Test NLL 0.6958130598068237
# [INFO] - 2024-05-15 18:58:59,986 - UQpy: Scientific Machine Learning: Epoch 100 / 1,000 Train Loss 1.6101300088982833 Train NLL 0.8363020310276433 Train KL 77382808.0 Test NLL 1.087916374206543
# [INFO] - 2024-05-15 18:59:03,948 - UQpy: Scientific Machine Learning: Epoch 101 / 1,000 Train Loss 1.6952190838362042 Train NLL 0.9219182227787218 Train KL 77330080.0 Test NLL 1.2222875356674194
# [INFO] - 2024-05-15 18:59:07,936 - UQpy: Scientific Machine Learning: Epoch 102 / 1,000 Train Loss 1.5481842066112317 Train NLL 0.7754305569749129 Train KL 77275368.0 Test NLL 0.9168856143951416
# [INFO] - 2024-05-15 18:59:11,868 - UQpy: Scientific Machine Learning: Epoch 103 / 1,000 Train Loss 1.4832800438529568 Train NLL 0.7111235166850843 Train KL 77215656.0 Test NLL 0.8436001539230347
# [INFO] - 2024-05-15 18:59:15,815 - UQpy: Scientific Machine Learning: Epoch 104 / 1,000 Train Loss 1.6160458138114528 Train NLL 0.8445098556970295 Train KL 77153592.0 Test NLL 0.6742619276046753
# [INFO] - 2024-05-15 18:59:19,704 - UQpy: Scientific Machine Learning: Epoch 105 / 1,000 Train Loss 1.5893903406042802 Train NLL 0.8184695071295688 Train KL 77092080.0 Test NLL 0.7323517799377441
# [INFO] - 2024-05-15 18:59:23,723 - UQpy: Scientific Machine Learning: Epoch 106 / 1,000 Train Loss 1.4696415913732428 Train NLL 0.6993430178416403 Train KL 77029856.0 Test NLL 0.9485200643539429
# [INFO] - 2024-05-15 18:59:27,724 - UQpy: Scientific Machine Learning: Epoch 107 / 1,000 Train Loss 1.806461120906629 Train NLL 1.036783805018977 Train KL 76967720.0 Test NLL 1.0422884225845337
# [INFO] - 2024-05-15 18:59:31,651 - UQpy: Scientific Machine Learning: Epoch 108 / 1,000 Train Loss 1.6929788024801957 Train NLL 0.9239224258222078 Train KL 76905632.0 Test NLL 1.0004340410232544
# [INFO] - 2024-05-15 18:59:35,735 - UQpy: Scientific Machine Learning: Epoch 109 / 1,000 Train Loss 1.7016831636428833 Train NLL 0.9332561587032518 Train KL 76842696.0 Test NLL 0.8819386959075928
# [INFO] - 2024-05-15 18:59:39,767 - UQpy: Scientific Machine Learning: Epoch 110 / 1,000 Train Loss 1.7056043587232892 Train NLL 0.93779498652408 Train KL 76780928.0 Test NLL 1.2076232433319092
# [INFO] - 2024-05-15 18:59:43,831 - UQpy: Scientific Machine Learning: Epoch 111 / 1,000 Train Loss 1.7476723194122314 Train NLL 0.9804886422659221 Train KL 76718360.0 Test NLL 0.8193323612213135
# [INFO] - 2024-05-15 18:59:47,953 - UQpy: Scientific Machine Learning: Epoch 112 / 1,000 Train Loss 1.7989777452067326 Train NLL 1.0324086578268754 Train KL 76656912.0 Test NLL 0.998799204826355
# [INFO] - 2024-05-15 18:59:52,043 - UQpy: Scientific Machine Learning: Epoch 113 / 1,000 Train Loss 1.8352754053316618 Train NLL 1.06932333582326 Train KL 76595216.0 Test NLL 1.3118829727172852
# [INFO] - 2024-05-15 18:59:56,131 - UQpy: Scientific Machine Learning: Epoch 114 / 1,000 Train Loss 1.7375324337106002 Train NLL 0.9721736876588118 Train KL 76535872.0 Test NLL 1.51376211643219
# [INFO] - 2024-05-15 19:00:00,116 - UQpy: Scientific Machine Learning: Epoch 115 / 1,000 Train Loss 1.5868699174178273 Train NLL 0.822032348105782 Train KL 76483760.0 Test NLL 1.1614625453948975
# [INFO] - 2024-05-15 19:00:04,048 - UQpy: Scientific Machine Learning: Epoch 116 / 1,000 Train Loss 1.7334105780250149 Train NLL 0.9691604815031353 Train KL 76425008.0 Test NLL 1.0040488243103027
# [INFO] - 2024-05-15 19:00:07,932 - UQpy: Scientific Machine Learning: Epoch 117 / 1,000 Train Loss 1.5715625662552684 Train NLL 0.8079464843398646 Train KL 76361608.0 Test NLL 0.8927779197692871
# [INFO] - 2024-05-15 19:00:11,805 - UQpy: Scientific Machine Learning: Epoch 118 / 1,000 Train Loss 1.5871994871842234 Train NLL 0.8242294506022805 Train KL 76297008.0 Test NLL 1.0815017223358154
# [INFO] - 2024-05-15 19:00:15,740 - UQpy: Scientific Machine Learning: Epoch 119 / 1,000 Train Loss 1.7605426248751188 Train NLL 0.9982306204344097 Train KL 76231200.0 Test NLL 2.158003807067871
# [INFO] - 2024-05-15 19:00:19,728 - UQpy: Scientific Machine Learning: Epoch 120 / 1,000 Train Loss 1.600048303604126 Train NLL 0.8383930921554565 Train KL 76165528.0 Test NLL 0.7607134580612183
# [INFO] - 2024-05-15 19:00:23,659 - UQpy: Scientific Machine Learning: Epoch 121 / 1,000 Train Loss 1.527537283144499 Train NLL 0.7664938176933088 Train KL 76104344.0 Test NLL 1.0028784275054932
# [INFO] - 2024-05-15 19:00:27,753 - UQpy: Scientific Machine Learning: Epoch 122 / 1,000 Train Loss 1.5279695109317177 Train NLL 0.7675445864075109 Train KL 76042496.0 Test NLL 0.7688448429107666
# [INFO] - 2024-05-15 19:00:31,825 - UQpy: Scientific Machine Learning: Epoch 123 / 1,000 Train Loss 1.5432397880052264 Train NLL 0.7834497847055134 Train KL 75979000.0 Test NLL 0.8715869188308716
# [INFO] - 2024-05-15 19:00:35,849 - UQpy: Scientific Machine Learning: Epoch 124 / 1,000 Train Loss 1.4885406180431968 Train NLL 0.7294146842078159 Train KL 75912592.0 Test NLL 0.7985198497772217
# [INFO] - 2024-05-15 19:00:39,805 - UQpy: Scientific Machine Learning: Epoch 125 / 1,000 Train Loss 1.599385274083991 Train NLL 0.8409439544928702 Train KL 75844128.0 Test NLL 1.2190001010894775
# [INFO] - 2024-05-15 19:00:43,706 - UQpy: Scientific Machine Learning: Epoch 126 / 1,000 Train Loss 1.4334062400617098 Train NLL 0.6756566088450583 Train KL 75774968.0 Test NLL 0.6986839771270752
# [INFO] - 2024-05-15 19:00:47,630 - UQpy: Scientific Machine Learning: Epoch 127 / 1,000 Train Loss 1.5789286086433811 Train NLL 0.8218679490842318 Train KL 75706072.0 Test NLL 0.8578246831893921
# [INFO] - 2024-05-15 19:00:51,527 - UQpy: Scientific Machine Learning: Epoch 128 / 1,000 Train Loss 1.5091821582693803 Train NLL 0.7528106460445806 Train KL 75637144.0 Test NLL 0.760758638381958
# [INFO] - 2024-05-15 19:00:55,473 - UQpy: Scientific Machine Learning: Epoch 129 / 1,000 Train Loss 1.4302650878303929 Train NLL 0.6745730011086715 Train KL 75569208.0 Test NLL 1.420153260231018
# [INFO] - 2024-05-15 19:00:59,465 - UQpy: Scientific Machine Learning: Epoch 130 / 1,000 Train Loss 1.5886065708963495 Train NLL 0.833606409399133 Train KL 75500016.0 Test NLL 0.7113171815872192
# [INFO] - 2024-05-15 19:01:03,434 - UQpy: Scientific Machine Learning: Epoch 131 / 1,000 Train Loss 1.3959105516734875 Train NLL 0.6416004770680478 Train KL 75431008.0 Test NLL 0.7192426919937134
# [INFO] - 2024-05-15 19:01:07,370 - UQpy: Scientific Machine Learning: Epoch 132 / 1,000 Train Loss 1.6162939636330855 Train NLL 0.8626838122543535 Train KL 75361008.0 Test NLL 0.89035564661026
# [INFO] - 2024-05-15 19:01:11,270 - UQpy: Scientific Machine Learning: Epoch 133 / 1,000 Train Loss 1.49046454304143 Train NLL 0.7375580166515551 Train KL 75290656.0 Test NLL 0.965366780757904
# [INFO] - 2024-05-15 19:01:15,299 - UQpy: Scientific Machine Learning: Epoch 134 / 1,000 Train Loss 1.432586864421242 Train NLL 0.6803892709706959 Train KL 75219760.0 Test NLL 0.8270881772041321
# [INFO] - 2024-05-15 19:01:19,344 - UQpy: Scientific Machine Learning: Epoch 135 / 1,000 Train Loss 1.5563785527881824 Train NLL 0.8048922090153945 Train KL 75148640.0 Test NLL 0.9585928916931152
# [INFO] - 2024-05-15 19:01:23,403 - UQpy: Scientific Machine Learning: Epoch 136 / 1,000 Train Loss 1.5875218541998612 Train NLL 0.8367360532283783 Train KL 75078592.0 Test NLL 0.8897978663444519
# [INFO] - 2024-05-15 19:01:27,410 - UQpy: Scientific Machine Learning: Epoch 137 / 1,000 Train Loss 1.6354744308873226 Train NLL 0.8853929042816162 Train KL 75008152.0 Test NLL 1.252200961112976
# [INFO] - 2024-05-15 19:01:31,419 - UQpy: Scientific Machine Learning: Epoch 138 / 1,000 Train Loss 1.7069939876857556 Train NLL 0.9576159276460346 Train KL 74937816.0 Test NLL 1.3498048782348633
# [INFO] - 2024-05-15 19:01:35,695 - UQpy: Scientific Machine Learning: Epoch 139 / 1,000 Train Loss 1.9966241309517307 Train NLL 1.2479526212340908 Train KL 74867144.0 Test NLL 1.4342806339263916
# [INFO] - 2024-05-15 19:01:39,751 - UQpy: Scientific Machine Learning: Epoch 140 / 1,000 Train Loss 1.92672556325009 Train NLL 1.178739883397755 Train KL 74798568.0 Test NLL 0.813948929309845
# [INFO] - 2024-05-15 19:01:43,749 - UQpy: Scientific Machine Learning: Epoch 141 / 1,000 Train Loss 1.6307847939039533 Train NLL 0.8834858034786425 Train KL 74729888.0 Test NLL 0.7841243743896484
# [INFO] - 2024-05-15 19:01:48,291 - UQpy: Scientific Machine Learning: Epoch 142 / 1,000 Train Loss 1.4654190289346796 Train NLL 0.71882322116902 Train KL 74659584.0 Test NLL 0.865540623664856
# [INFO] - 2024-05-15 19:01:52,393 - UQpy: Scientific Machine Learning: Epoch 143 / 1,000 Train Loss 1.5118832274487144 Train NLL 0.7660093417293147 Train KL 74587392.0 Test NLL 0.7482249736785889
# [INFO] - 2024-05-15 19:01:56,732 - UQpy: Scientific Machine Learning: Epoch 144 / 1,000 Train Loss 1.4270770863482827 Train NLL 0.6819258504792264 Train KL 74515128.0 Test NLL 0.8476744890213013
# [INFO] - 2024-05-15 19:02:00,760 - UQpy: Scientific Machine Learning: Epoch 145 / 1,000 Train Loss 1.424492974030344 Train NLL 0.6800191324008139 Train KL 74447384.0 Test NLL 0.7493102550506592
# [INFO] - 2024-05-15 19:02:04,971 - UQpy: Scientific Machine Learning: Epoch 146 / 1,000 Train Loss 1.4329221374110173 Train NLL 0.6891338323291979 Train KL 74378832.0 Test NLL 0.8932169675827026
# [INFO] - 2024-05-15 19:02:08,993 - UQpy: Scientific Machine Learning: Epoch 147 / 1,000 Train Loss 1.5229393996690448 Train NLL 0.7798497582736769 Train KL 74308968.0 Test NLL 1.4506640434265137
# [INFO] - 2024-05-15 19:02:13,063 - UQpy: Scientific Machine Learning: Epoch 148 / 1,000 Train Loss 1.6758705440320467 Train NLL 0.933495935640837 Train KL 74237464.0 Test NLL 1.0338037014007568
# [INFO] - 2024-05-15 19:02:17,025 - UQpy: Scientific Machine Learning: Epoch 149 / 1,000 Train Loss 1.4471396019584255 Train NLL 0.7054913106717562 Train KL 74164824.0 Test NLL 0.9086934328079224
# [INFO] - 2024-05-15 19:02:21,087 - UQpy: Scientific Machine Learning: Epoch 150 / 1,000 Train Loss 1.3943067600852566 Train NLL 0.6533997152981005 Train KL 74090704.0 Test NLL 1.0685975551605225
# [INFO] - 2024-05-15 19:02:25,052 - UQpy: Scientific Machine Learning: Epoch 151 / 1,000 Train Loss 1.4179273090864484 Train NLL 0.6777716812334562 Train KL 74015560.0 Test NLL 1.2975376844406128
# [INFO] - 2024-05-15 19:02:29,075 - UQpy: Scientific Machine Learning: Epoch 152 / 1,000 Train Loss 1.51817692580976 Train NLL 0.7787772197472421 Train KL 73939976.0 Test NLL 0.7733407020568848
# [INFO] - 2024-05-15 19:02:32,988 - UQpy: Scientific Machine Learning: Epoch 153 / 1,000 Train Loss 1.4286960865321912 Train NLL 0.6900461457277599 Train KL 73864984.0 Test NLL 0.7497929334640503
# [INFO] - 2024-05-15 19:02:36,948 - UQpy: Scientific Machine Learning: Epoch 154 / 1,000 Train Loss 1.5694008689177663 Train NLL 0.8315064060060602 Train KL 73789440.0 Test NLL 0.8488012552261353
# [INFO] - 2024-05-15 19:02:40,893 - UQpy: Scientific Machine Learning: Epoch 155 / 1,000 Train Loss 1.570784562512448 Train NLL 0.8336348941451625 Train KL 73714968.0 Test NLL 0.8002915382385254
# [INFO] - 2024-05-15 19:02:44,945 - UQpy: Scientific Machine Learning: Epoch 156 / 1,000 Train Loss 1.5299835581528514 Train NLL 0.7935880359850431 Train KL 73639560.0 Test NLL 1.023837685585022
# [INFO] - 2024-05-15 19:02:48,931 - UQpy: Scientific Machine Learning: Epoch 157 / 1,000 Train Loss 1.5324379080220272 Train NLL 0.7968060311518217 Train KL 73563184.0 Test NLL 1.013390064239502
# [INFO] - 2024-05-15 19:02:52,978 - UQpy: Scientific Machine Learning: Epoch 158 / 1,000 Train Loss 1.583519552883349 Train NLL 0.848642669225994 Train KL 73487696.0 Test NLL 1.0450224876403809
# [INFO] - 2024-05-15 19:02:56,967 - UQpy: Scientific Machine Learning: Epoch 159 / 1,000 Train Loss 1.6709580546931218 Train NLL 0.9368224661601218 Train KL 73413568.0 Test NLL 0.8144723773002625
# [INFO] - 2024-05-15 19:03:01,009 - UQpy: Scientific Machine Learning: Epoch 160 / 1,000 Train Loss 1.8238675280621177 Train NLL 1.0904625246399327 Train KL 73340496.0 Test NLL 0.750542402267456
# [INFO] - 2024-05-15 19:03:05,000 - UQpy: Scientific Machine Learning: Epoch 161 / 1,000 Train Loss 1.6702361734289872 Train NLL 0.9375543484562322 Train KL 73268184.0 Test NLL 0.9817202091217041
# [INFO] - 2024-05-15 19:03:08,958 - UQpy: Scientific Machine Learning: Epoch 162 / 1,000 Train Loss 1.5682611779162758 Train NLL 0.8363136680502641 Train KL 73194752.0 Test NLL 0.8611934185028076
# [INFO] - 2024-05-15 19:03:12,937 - UQpy: Scientific Machine Learning: Epoch 163 / 1,000 Train Loss 1.3268990014728748 Train NLL 0.595708672937594 Train KL 73119032.0 Test NLL 0.6577324867248535
# [INFO] - 2024-05-15 19:03:16,985 - UQpy: Scientific Machine Learning: Epoch 164 / 1,000 Train Loss 1.3714420544473749 Train NLL 0.6410346203728726 Train KL 73040752.0 Test NLL 0.6888606548309326
# [INFO] - 2024-05-15 19:03:20,958 - UQpy: Scientific Machine Learning: Epoch 165 / 1,000 Train Loss 1.392029843832317 Train NLL 0.6624150401667545 Train KL 72961472.0 Test NLL 1.031724452972412
# [INFO] - 2024-05-15 19:03:25,078 - UQpy: Scientific Machine Learning: Epoch 166 / 1,000 Train Loss 1.5460184624320583 Train NLL 0.8172029162708082 Train KL 72881560.0 Test NLL 0.7211873531341553
# [INFO] - 2024-05-15 19:03:29,467 - UQpy: Scientific Machine Learning: Epoch 167 / 1,000 Train Loss 1.3724565129531057 Train NLL 0.6444345242098758 Train KL 72802200.0 Test NLL 0.7270209193229675
# [INFO] - 2024-05-15 19:03:33,565 - UQpy: Scientific Machine Learning: Epoch 168 / 1,000 Train Loss 1.459104017207497 Train NLL 0.7318790492258573 Train KL 72722496.0 Test NLL 0.761635422706604
# [INFO] - 2024-05-15 19:03:37,658 - UQpy: Scientific Machine Learning: Epoch 169 / 1,000 Train Loss 1.4648030870839168 Train NLL 0.7383790016174316 Train KL 72642408.0 Test NLL 0.7860204577445984
# [INFO] - 2024-05-15 19:03:41,654 - UQpy: Scientific Machine Learning: Epoch 170 / 1,000 Train Loss 1.5945511052483006 Train NLL 0.8689329937884682 Train KL 72561816.0 Test NLL 0.6806238889694214
# [INFO] - 2024-05-15 19:03:45,798 - UQpy: Scientific Machine Learning: Epoch 171 / 1,000 Train Loss 1.4575239921870984 Train NLL 0.732701113349513 Train KL 72482280.0 Test NLL 0.7319011688232422
# [INFO] - 2024-05-15 19:03:49,901 - UQpy: Scientific Machine Learning: Epoch 172 / 1,000 Train Loss 1.5452104806900024 Train NLL 0.8211857300055655 Train KL 72402480.0 Test NLL 1.599368929862976
# [INFO] - 2024-05-15 19:03:54,015 - UQpy: Scientific Machine Learning: Epoch 173 / 1,000 Train Loss 1.5946713874214573 Train NLL 0.8714506061453569 Train KL 72322080.0 Test NLL 0.7422225475311279
# [INFO] - 2024-05-15 19:03:58,378 - UQpy: Scientific Machine Learning: Epoch 174 / 1,000 Train Loss 1.4247535718114752 Train NLL 0.7023074658293473 Train KL 72244608.0 Test NLL 0.8803686499595642
# [INFO] - 2024-05-15 19:04:02,511 - UQpy: Scientific Machine Learning: Epoch 175 / 1,000 Train Loss 1.4417211821204738 Train NLL 0.7200724466850883 Train KL 72164872.0 Test NLL 0.8764950037002563
# [INFO] - 2024-05-15 19:04:06,593 - UQpy: Scientific Machine Learning: Epoch 176 / 1,000 Train Loss 1.4438133616196482 Train NLL 0.7229727538008439 Train KL 72084064.0 Test NLL 0.8701310157775879
# [INFO] - 2024-05-15 19:04:10,566 - UQpy: Scientific Machine Learning: Epoch 177 / 1,000 Train Loss 1.6537450614728426 Train NLL 0.9337245665098491 Train KL 72002048.0 Test NLL 1.0634950399398804
# [INFO] - 2024-05-15 19:04:14,517 - UQpy: Scientific Machine Learning: Epoch 178 / 1,000 Train Loss 1.6260242211191278 Train NLL 0.9068099354442797 Train KL 71921432.0 Test NLL 0.7594133615493774
# [INFO] - 2024-05-15 19:04:18,558 - UQpy: Scientific Machine Learning: Epoch 179 / 1,000 Train Loss 1.5993456903256869 Train NLL 0.8809331812356648 Train KL 71841248.0 Test NLL 1.3989628553390503
# [INFO] - 2024-05-15 19:04:22,891 - UQpy: Scientific Machine Learning: Epoch 180 / 1,000 Train Loss 1.424860722140262 Train NLL 0.707240503085287 Train KL 71762024.0 Test NLL 0.9104658961296082
# [INFO] - 2024-05-15 19:04:27,333 - UQpy: Scientific Machine Learning: Epoch 181 / 1,000 Train Loss 1.5175362637168484 Train NLL 0.800738297010723 Train KL 71679808.0 Test NLL 0.9986529350280762
# [INFO] - 2024-05-15 19:04:31,926 - UQpy: Scientific Machine Learning: Epoch 182 / 1,000 Train Loss 1.430960266213668 Train NLL 0.7149734104934492 Train KL 71598696.0 Test NLL 0.7658311128616333
# [INFO] - 2024-05-15 19:04:35,957 - UQpy: Scientific Machine Learning: Epoch 183 / 1,000 Train Loss 1.4327345459084762 Train NLL 0.7175212973042538 Train KL 71521320.0 Test NLL 1.1715953350067139
# [INFO] - 2024-05-15 19:04:40,086 - UQpy: Scientific Machine Learning: Epoch 184 / 1,000 Train Loss 1.4548177468149286 Train NLL 0.7403596890600104 Train KL 71445808.0 Test NLL 0.8941707611083984
# [INFO] - 2024-05-15 19:04:44,173 - UQpy: Scientific Machine Learning: Epoch 185 / 1,000 Train Loss 1.4314533723028082 Train NLL 0.7177861113297311 Train KL 71366720.0 Test NLL 0.7797709703445435
# [INFO] - 2024-05-15 19:04:48,247 - UQpy: Scientific Machine Learning: Epoch 186 / 1,000 Train Loss 1.4545572368722213 Train NLL 0.7417210246387281 Train KL 71283616.0 Test NLL 0.8488819599151611
# [INFO] - 2024-05-15 19:04:52,264 - UQpy: Scientific Machine Learning: Epoch 187 / 1,000 Train Loss 1.5405769912820113 Train NLL 0.8285744692149916 Train KL 71200256.0 Test NLL 0.8285862803459167
# [INFO] - 2024-05-15 19:04:56,229 - UQpy: Scientific Machine Learning: Epoch 188 / 1,000 Train Loss 1.4439277962634438 Train NLL 0.7327694328207719 Train KL 71115840.0 Test NLL 0.8451099395751953
# [INFO] - 2024-05-15 19:05:00,187 - UQpy: Scientific Machine Learning: Epoch 189 / 1,000 Train Loss 1.425124300153632 Train NLL 0.7148208727962092 Train KL 71030336.0 Test NLL 0.8807860612869263
# [INFO] - 2024-05-15 19:05:04,228 - UQpy: Scientific Machine Learning: Epoch 190 / 1,000 Train Loss 1.5169632183878046 Train NLL 0.8075269476363534 Train KL 70943632.0 Test NLL 0.7034927606582642
# [INFO] - 2024-05-15 19:05:08,201 - UQpy: Scientific Machine Learning: Epoch 191 / 1,000 Train Loss 1.3665973387266461 Train NLL 0.65801602602005 Train KL 70858128.0 Test NLL 0.6627346277236938
# [INFO] - 2024-05-15 19:05:12,179 - UQpy: Scientific Machine Learning: Epoch 192 / 1,000 Train Loss 1.3288347972066779 Train NLL 0.621124068373128 Train KL 70771080.0 Test NLL 0.6318073272705078
# [INFO] - 2024-05-15 19:05:16,202 - UQpy: Scientific Machine Learning: Epoch 193 / 1,000 Train Loss 1.427285872007671 Train NLL 0.7204467293463255 Train KL 70683928.0 Test NLL 0.6264578700065613
# [INFO] - 2024-05-15 19:05:20,125 - UQpy: Scientific Machine Learning: Epoch 194 / 1,000 Train Loss 1.3100086325093319 Train NLL 0.6040408705410204 Train KL 70596776.0 Test NLL 0.6291309595108032
# [INFO] - 2024-05-15 19:05:24,142 - UQpy: Scientific Machine Learning: Epoch 195 / 1,000 Train Loss 1.3926426987898977 Train NLL 0.6875418361864591 Train KL 70510088.0 Test NLL 0.6585881114006042
# [INFO] - 2024-05-15 19:05:28,091 - UQpy: Scientific Machine Learning: Epoch 196 / 1,000 Train Loss 1.6401909464283992 Train NLL 0.9359712286999351 Train KL 70421968.0 Test NLL 0.9446053504943848
# [INFO] - 2024-05-15 19:05:32,104 - UQpy: Scientific Machine Learning: Epoch 197 / 1,000 Train Loss 1.5372859114094783 Train NLL 0.8339375743740484 Train KL 70334832.0 Test NLL 0.970689058303833
# [INFO] - 2024-05-15 19:05:36,130 - UQpy: Scientific Machine Learning: Epoch 198 / 1,000 Train Loss 1.4265898654335423 Train NLL 0.7241190891516837 Train KL 70247080.0 Test NLL 1.0571990013122559
# [INFO] - 2024-05-15 19:05:40,133 - UQpy: Scientific Machine Learning: Epoch 199 / 1,000 Train Loss 1.513722488754674 Train NLL 0.8121366030291507 Train KL 70158584.0 Test NLL 0.6914782524108887
# [INFO] - 2024-05-15 19:05:44,074 - UQpy: Scientific Machine Learning: Epoch 200 / 1,000 Train Loss 1.382830864504764 Train NLL 0.682130753993988 Train KL 70070016.0 Test NLL 0.6397051811218262
# [INFO] - 2024-05-15 19:05:48,030 - UQpy: Scientific Machine Learning: Epoch 201 / 1,000 Train Loss 1.2557984465046932 Train NLL 0.5559918582439423 Train KL 69980656.0 Test NLL 0.8669605255126953

# %%
train_loss = trainer.history["train_loss"].detach().numpy()
test_loss = trainer.history["test_nll"].detach().numpy()
fig, ax = plt.subplots()
ax.plot(train_loss)
ax.plot(test_loss)
ax.set_title("Bayes By Backpropagation Training Loss")
ax.set(xlabel="Epoch", ylabel="Loss")
ax.set_yscale('log')

# %%
# Evaluate test data and save results
def eval_model(test_data,model):
    model.eval()
    ux_pred_list = []
    uy_pred_list = []
    ux_test_list = []
    uy_test_list = []
    x_list = []
    for batch_number, (*x, y) in enumerate(test_data):
        ux_pred, uy_pred = model(*x)
        ux_test , uy_test = y
        ux_pred_list.append(ux_pred)
        uy_pred_list.append(uy_pred)
        ux_test_list.append(ux_test)
        uy_test_list.append(uy_test)
        x_list.append(x[1][:,0,:])
    return torch.cat(ux_pred_list), torch.cat(uy_pred_list), torch.cat(ux_test_list), torch.cat(uy_test_list), torch.cat(x_list)

# %%
ux_pred, uy_pred, ux_test, uy_test, x_test = eval_model(test_data,model)
ux_pred = rescale(ux_pred.detach(), np.squeeze(ux_train_mean, axis=2), np.squeeze(ux_train_std, axis=2))
uy_pred = rescale(uy_pred.detach(), np.squeeze(uy_train_mean, axis=2), np.squeeze(uy_train_std, axis=2))
ux_test = rescale(ux_test.detach(), np.squeeze(ux_train_mean, axis=2), np.squeeze(ux_train_std, axis=2))
uy_test = rescale(uy_test.detach(), np.squeeze(uy_train_mean, axis=2), np.squeeze(uy_train_std, axis=2))

# %%
savemat('Bayesian_Elastic_plate.mat',{'x_test': x_test.detach().numpy(), 'ux_test': ux_test.detach().numpy(), 'uy_test': uy_test.detach().numpy(), 
                              'ux_pred': ux_pred.detach().numpy(), 'uy_pred': uy_pred.detach().numpy()} )
